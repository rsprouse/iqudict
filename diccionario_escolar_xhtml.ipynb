# %% [markdown]
# # Diccionario escolar
#
# A full entry consists of the following fields in the following order:
#
# 1. Citation Form
# 2. Gram. info (Abbrev. spn)
# 3. Glosses (Gae)
# 4. Variant Form (Iqu) [if present]
#
# A minimal entry is a reduced entry that refers back to full entry, and consists of the following fields in the following order:
#
# 1. Citation Form
# 2. Variant Type (Reverse name, spn)
# 3. Variant of

# %%
import xml.etree.ElementTree as ET

# %%
infile = 'iqu_flex_export/FLEx_LIFT_20181017.lift.xml'
#reversaldict = 'iqu_ped_dict_rev_17apr2019.xhtml'
ns = {'default': 'http://www.w3.org/1999/xhtml'}

# %%
tree = ET.parse(infile)
root = tree.getroot()

entries = root.findall('entry')

# %%
def nodetext(node):
    '''Return all text found in node as a string.'''
    return ''.join(list(node.itertext()))

def get_headword(e):
    '''Return an entry's headword. Throw an error if entry's headword fields are missing
    or empty.'''
    try:
        hdwd = nodetext(e.find('citation/form[@lang="iqu"]/text')).strip()
        assert(hdwd is not None)
    except (AttributeError, AssertionError):
        hdwd = nodetext(e.find('lexical-unit/form[@lang="iqu"]/text')).strip()
        assert(hdwd is not None)
    return hdwd

def glosses2tex(e, lang):
    '''Return senses in latex format.'''
    tex = ''
    senses = e.findall('sense')
    for idx, s in enumerate(senses):
        tex += '  \\glosses{'
        if len(senses) > 1:
            tex += '{:d}. '.format(idx + 1)
        tex += '\n'
        try:
            glosses = s.findall('gloss[@lang="' + lang + '"]/text')
            for gloss in glosses:
                tex += '    \\gloss{' + ''.join(gloss.itertext()) + '}\n'
        except (AttributeError, TypeError):
            pass
#        try:
#            ginfo = s.find('grammatical-info').attrib['value']
#            tex += '    \\grammaticalinfo{' + ginfo + '}\n'
#        except AttributeError:
#            pass
#        tex += simplefield2tex(s, 'grammaticalnote', 'note[@type="grammar"]/form[@lang="eng"]/text', level=2)
#        tex += examples2tex(s)
        tex += '  }\n'
    return tex

def get_glosses(e):
    nodes = e.findall('.//default:span[@lang="ga"]', ns)
    if len(nodes) == 0:
        gl = ''
    elif len(nodes) == 1:
        gl = r'\gloss{ ' + nodetext(nodes[0]) + ' } '
    elif len(nodes) > 1:
        gl = [r'\gloss{ ' + str(idx+1) + '. ' + nodetext(n) + ' } ' for idx, n in enumerate(nodes)] 
        gl = ' '.join(gl)
    return gl

def get_variants(e, root):
    eid = '#' + e.attrib['id']
    variants = root.findall('.//default:div[@class="minorentryvariant"]//default:span[@class="referencedentry"]//default:a[@href="{:}"]'.format(eid), ns)
    # TODO: from each variant, go up to <div and then down to span[@class="headword"] to find content for variant
    if len(variants) == 0:
        vstr = ''
    elif len(variants) == 1:
        vstr = r'\variants{ Variante: ' + nodetext(variants[0]) + '} '
    else:
        vstr = r'\variants{ Variantes: ' + ', '.join([nodetext(n) for n in variants]) + '} '
    return vstr

def entry2latex(e):
    tex = '\entry{\n'
    tex += '\headword{' + get_headword(e) + '}\n'
    tex += glosses2tex(e, lang='ga')
    return tex
#    gram = e.find('.//default:span[@class="morphosyntaxanalysis"]//default:span[@lang="es"]', ns)
#    glosses = get_glosses(e)
#variants = get_variants(e, root)
#    ltx = \
#        r'\entry{ ' \
#        + r'\hdwd{ ' + nodetext(hdwd) + '} ' \
#        + r'\gram{ ' + nodetext(gram) + '} ' \
#        + glosses \
#        + variants \
#        + '} '
#    return ltx
        
def minorentry2latex(e):
    hdwd = e.find('.//default:span[@class="headword"]', ns)
    variant = e.find('.//default:span[@class="referencedentry"]//default:span[@lang="iqu"]', ns)
    ltx = \
        r'\entry{ ' \
        + r'\hdwd{ ' + nodetext(hdwd) + '} ' \
        + r'\variant{ Ver: ' + nodetext(variant) + '} ' \
        + '} '
    return ltx

# %%
for e in entries:
    ltx = entry2latex(e)
    print(ltx)
# Out:
# \entry{
# \headword{=karíjata}
#   \glosses{
#     \gloss{vista}
#   }
#
# \entry{
# \headword{kuupɨkiiraata}
#   \glosses{
#     \gloss{entre dos no más}
#   }
#
# \entry{
# \headword{parikɨɨtáani}
#   \glosses{
#     \gloss{estar.cerca.al.suelo}
#   }
#
# \entry{
# \headword{anijákwaa}
#   \glosses{
#     \gloss{grande, para algo que normalmente sería más pequeño, por ejemplo una gallina}
#   }
#
# \entry{
# \headword{tiitiwa}
#   \glosses{
#     \gloss{pie.pl}
#   }
#
# \entry{
# \headword{maájarina}
#   \glosses{
#   }
#
# \entry{
# \headword{kwaata}
#   \glosses{1.
#     \gloss{claramente}
#   }
#   \glosses{2.
#     \gloss{claro}
#   }
#
# \entry{
# \headword{sakana}
#   \glosses{
#     \gloss{carahuasca, clase de árboles en general. PL: sakanaa}
#   }
#
# \entry{
# \headword{yaa}
#   \glosses{
#     \gloss{NOUN}
#   }
#
# \entry{
# \headword{jaátaraatina}
#   \glosses{
#     \gloss{que.clase}
#   }
#
# \entry{
# \headword{kaaya nikiiti}
#   \glosses{
#   }
#
# \entry{
# \headword{purisíiya}
#   \glosses{
#     \gloss{policia}
#   }
#
# \entry{
# \headword{faltaasíini}
#   \glosses{
#     \gloss{faltar.respeto}
#   }
#
# \entry{
# \headword{masɨɨtáani}
#   \glosses{
#     \gloss{tener los brazos abiertos. Raíz: masɨɨ́ta-}
#   }
#
# \entry{
# \headword{iyɨkúura}
#   \glosses{
#     \gloss{defensa}
#   }
#
# \entry{
# \headword{tanajɨɨtáani}
#   \glosses{
#     \gloss{ser.barrigón}
#   }
#
# \entry{
# \headword{siwíika sɨɨ́taari}
#   \glosses{
#     \gloss{paña.esp}
#   }
#
# \entry{
# \headword{tírina}
#   \glosses{
#     \gloss{torito}
#   }
#
# \entry{
# \headword{kuumáari}
#   \glosses{
#     \gloss{comadre}
#   }
#
# \entry{
# \headword{masiku túruuja}
#   \glosses{
#     \gloss{paucar.grande}
#   }
#
# \entry{
# \headword{iitiika}
#   \glosses{
#     \gloss{más.acá}
#   }
#
# \entry{
# \headword{tiiriwa}
#   \glosses{1.
#     \gloss{bola.pl}
#   }
#   \glosses{2.
#     \gloss{tobillo.pl}
#   }
#   \glosses{3.
#     \gloss{espuela.pl}
#   }
#
# \entry{
# \headword{puwaajɨ́ɨni}
#   \glosses{
#     \gloss{silvo}
#   }
#
# \entry{
# \headword{siíti}
#   \glosses{
#     \gloss{estirarse}
#   }
#
# \entry{
# \headword{jiina}
#   \glosses{
#     \gloss{desde}
#   }
#
# \entry{
# \headword{nawɨyakaka}
#   \glosses{1.
#     \gloss{almas}
#   }
#   \glosses{2.
#     \gloss{fotografías}
#   }
#
# \entry{
# \headword{amariyaajina}
#   \glosses{
#     \gloss{pijuayal}
#   }
#
# \entry{
# \headword{siyuúmani}
#   \glosses{
#   }
#
# \entry{
# \headword{amátana}
#   \glosses{
#     \gloss{con fuerza}
#   }
#
# \entry{
# \headword{makɨ́ɨni}
#   \glosses{
#     \gloss{sueño, lo que vemos cuando dormimos. PL; makɨ́ɨnika}
#   }
#
# \entry{
# \headword{kiaárika}
#   \glosses{
#     \gloss{usted o tú no más}
#   }
#
# \entry{
# \headword{ikwaniikáani}
#   \glosses{
#     \gloss{jovencito.voc}
#   }
#
# \entry{
# \headword{aaraaka}
#   \glosses{
#     \gloss{saliva. PL: aaraakaka}
#   }
#
# \entry{
# \headword{-jaáka}
#   \glosses{1.
#     \gloss{CL:huayo.suave}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{áaja irɨwɨ}
#   \glosses{
#     \gloss{vulva}
#   }
#
# \entry{
# \headword{samúkwaati imɨ́ɨya}
#   \glosses{
#     \gloss{gusano.sp.pl}
#   }
#
# \entry{
# \headword{sasaanúuni}
#   \glosses{
#     \gloss{make.float}
#   }
#
# \entry{
# \headword{saawáatu}
#   \glosses{
#     \gloss{sábado. PL: saawáatuka}
#   }
#
# \entry{
# \headword{ijirɨna}
#   \glosses{
#     \gloss{asiento}
#   }
#
# \entry{
# \headword{napɨniwa}
#   \glosses{
#     \gloss{chinche.pl}
#   }
#
# \entry{
# \headword{kaántaakɨ́ɨni}
#   \glosses{
#     \gloss{amenazar}
#   }
#
# \entry{
# \headword{paayuwa}
#   \glosses{
#     \gloss{demonio.tipo}
#   }
#
# \entry{
# \headword{kuki}
#   \glosses{
#     \gloss{chancarse}
#   }
#
# \entry{
# \headword{kɨ́ɨra}
#   \glosses{
#     \gloss{"¡pucha!" o "¡bruto!"--  una expresión de miedo o de asustarse}
#   }
#
# \entry{
# \headword{jíritiíkuku}
#   \glosses{
#     \gloss{por.el.medio}
#   }
#
# \entry{
# \headword{siinaki imáaku}
#   \glosses{
#     \gloss{comido.de.gusano}
#   }
#
# \entry{
# \headword{Murúuna}
#   \glosses{
#     \gloss{Moronacocha}
#   }
#
# \entry{
# \headword{nɨtɨtɨ́ɨni}
#   \glosses{1.
#     \gloss{hacer.correr}
#   }
#   \glosses{2.
#     \gloss{resbalar}
#   }
#
# \entry{
# \headword{kuwíini}
#   \glosses{
#     \gloss{ser, hablando de un tiempo futuro. Palabras relacionadas: tɨ́ɨ, táa. Raíz: kuúki-}
#   }
#
# \entry{
# \headword{naarikaja}
#   \glosses{
#     \gloss{"¡ya está ya!"}
#   }
#
# \entry{
# \headword{pantiiyáata}
#   \glosses{
#     \gloss{pandillada}
#   }
#
# \entry{
# \headword{kanawaara}
#   \glosses{
#     \gloss{amigo}
#   }
#
# \entry{
# \headword{-Ø}
#   \glosses{
#     \gloss{ADVR}
#   }
#
# \entry{
# \headword{puúruwura}
#   \glosses{
#     \gloss{pólvora}
#   }
#
# \entry{
# \headword{nasiki}
#   \glosses{
#     \gloss{quebrarse.en.dos}
#   }
#
# \entry{
# \headword{yaasiita}
#   \glosses{
#     \gloss{doble o grueso. Dicho cuando mostramos la doblura de algo}
#   }
#
# \entry{
# \headword{siwánaka}
#   \glosses{
#   }
#
# \entry{
# \headword{inájaakɨ́ɨni}
#   \glosses{
#     \gloss{asustar.varias.veces}
#   }
#
# \entry{
# \headword{kajati}
#   \glosses{
#     \gloss{caerse.el.pelo}
#   }
#
# \entry{
# \headword{nɨɨkajúuni}
#   \glosses{1.
#     \gloss{cortar.en.rajas}
#   }
#   \glosses{2.
#     \gloss{repartir}
#   }
#
# \entry{
# \headword{iijakarikuku}
#   \glosses{
#     \gloss{subida.de.loma}
#   }
#
# \entry{
# \headword{-ta}
#   \glosses{
#     \gloss{VCL:recip.lleno}
#   }
#
# \entry{
# \headword{Aatáaja}
#   \glosses{
#     \gloss{personaje.histórico}
#   }
#
# \entry{
# \headword{sawiyɨɨjɨɨ́ta}
#   \glosses{
#     \gloss{tener.mareos}
#   }
#
# \entry{
# \headword{pujuniwɨɨtáani}
#   \glosses{
#     \gloss{mostrar.senales}
#   }
#
# \entry{
# \headword{juúni}
#   \glosses{
#     \gloss{fumar}
#   }
#
# \entry{
# \headword{kinikúura}
#   \glosses{1.
#     \gloss{más.allá}
#   }
#   \glosses{2.
#     \gloss{más.río.arriba.hacia.destinario}
#   }
#
# \entry{
# \headword{sikiáaja sawija}
#   \glosses{
#     \gloss{cascajo}
#   }
#
# \entry{
# \headword{ijiíti}
#   \glosses{
#     \gloss{estar sentado}
#   }
#
# \entry{
# \headword{nimúuni}
#   \glosses{
#     \gloss{tirar.birote}
#   }
#
# \entry{
# \headword{nɨ́ɨja}
#   \glosses{
#     \gloss{su.tubérculo}
#   }
#
# \entry{
# \headword{sarawaasíini}
#   \glosses{
#     \gloss{salvar}
#   }
#
# \entry{
# \headword{suuríija}
#   \glosses{
#     \gloss{rancho}
#   }
#
# \entry{
# \headword{miinari}
#   \glosses{
#     \gloss{piña.pl}
#   }
#
# \entry{
# \headword{karɨjɨ́ɨni}
#   \glosses{
#     \gloss{tener sed. Raíz: karɨɨ́jɨ-, karɨɨ́ji-}
#   }
#
# \entry{
# \headword{pájiiti}
#   \glosses{
#     \gloss{mandíbula.inferior}
#   }
#
# \entry{
# \headword{íjiija}
#   \glosses{
#     \gloss{paquete, envuelto en hoja. PL: íjiijaka}
#   }
#
# \entry{
# \headword{-jina}
#   \glosses{
#     \gloss{LOC}
#   }
#
# \entry{
# \headword{pajáti}
#   \glosses{
#   }
#
# \entry{
# \headword{Pukina}
#   \glosses{
#     \gloss{nombre.personal}
#   }
#
# \entry{
# \headword{iitiírakuma}
#   \glosses{
#     \gloss{hasta.acá}
#   }
#
# \entry{
# \headword{aamuútaaja}
#   \glosses{
#     \gloss{tipo de mazo. PL: aamuútaajaka }
#   }
#
# \entry{
# \headword{kaniyúuja niaatíija}
#   \glosses{1.
#     \gloss{madre.de.curhuince}
#   }
#   \glosses{2.
#     \gloss{madre.de.curhuince}
#   }
#
# \entry{
# \headword{Muumúumu}
#   \glosses{
#     \gloss{Nombre propio del río Momón}
#   }
#
# \entry{
# \headword{muyuutáani}
#   \glosses{
#   }
#
# \entry{
# \headword{jɨɨ́timijaárika}
#   \glosses{
#     \gloss{que.tamaño.pl.inan.}
#   }
#
# \entry{
# \headword{kurijati}
#   \glosses{
#     \gloss{dislocarse}
#   }
#
# \entry{
# \headword{kamuúnaari}
#   \glosses{
#     \gloss{tejido.de.irapay}
#   }
#
# \entry{
# \headword{iyakúura}
#   \glosses{
#     \gloss{defensa}
#   }
#
# \entry{
# \headword{jiritikúura}
#   \glosses{
#     \gloss{pecho, la parte interior. PL: jiritikuúraka}
#   }
#
# \entry{
# \headword{jirítikajina}
#   \glosses{
#   }
#
# \entry{
# \headword{sirviisíini}
#   \glosses{
#     \gloss{servir}
#   }
#
# \entry{
# \headword{inɨ́ɨku}
#   \glosses{
#     \gloss{choshna.pequeño}
#   }
#
# \entry{
# \headword{iijakarikuma}
#   \glosses{
#     \gloss{bajada.de.loma}
#   }
#
# \entry{
# \headword{asapɨ́ɨna}
#   \glosses{
#     \gloss{rama.chimicua}
#   }
#
# \entry{
# \headword{juu}
#   \glosses{
#     \gloss{"¡oy!" una expresión de sorpresa o admiración}
#   }
#
# \entry{
# \headword{tawánaja}
#   \glosses{
#     \gloss{tizón}
#   }
#
# \entry{
# \headword{tuwɨsɨ́kɨɨja}
#   \glosses{
#     \gloss{gusano.esp.}
#   }
#
# \entry{
# \headword{-ØHLL#}
#   \glosses{
#     \gloss{NON.PST}
#   }
#
# \entry{
# \headword{ES/SP}
#   \glosses{
#     \gloss{Castellano}
#   }
#
# \entry{
# \headword{jimati}
#   \glosses{
#     \gloss{salir}
#   }
#
# \entry{
# \headword{akasiitáani}
#   \glosses{
#     \gloss{estar agachado, tal como el trasero se extiende mucho. Raíz: akasiita-}
#   }
#
# \entry{
# \headword{akɨriíjanii}
#   \glosses{
#   }
#
# \entry{
# \headword{tɨɨ́tiiji}
#   \glosses{
#     \gloss{de dónde}
#   }
#
# \entry{
# \headword{-ta}
#   \glosses{
#     \gloss{VCL:part.mult}
#   }
#
# \entry{
# \headword{amuusíini}
#   \glosses{
#     \gloss{tener barba o bigote. Raíz: amuúsii-}
#   }
#
# \entry{
# \headword{mɨrɨ́ɨni}
#   \glosses{
#     \gloss{embarazar}
#   }
#
# \entry{
# \headword{akíkati}
#   \glosses{
#     \gloss{desramarse}
#   }
#
# \entry{
# \headword{pantiiyaasíini}
#   \glosses{
#     \gloss{pandillar}
#   }
#
# \entry{
# \headword{junɨɨnɨɨkɨɨtáani}
#   \glosses{
#     \gloss{soplar una brisa. }
#   }
#
# \entry{
# \headword{aáwɨya}
#   \glosses{
#     \gloss{tronera}
#   }
#
# \entry{
# \headword{-kisa}
#   \glosses{
#     \gloss{CL:canilla}
#   }
#
# \entry{
# \headword{aasamu siirɨ}
#   \glosses{
#     \gloss{lagarto.bolabola}
#   }
#
# \entry{
# \headword{tɨ́=}
#   \glosses{
#     \gloss{OPT}
#   }
#
# \entry{
# \headword{Siasiapúuya}
#   \glosses{
#     \gloss{Chachapoyas}
#   }
#
# \entry{
# \headword{kinikíira}
#   \glosses{1.
#     \gloss{allá.al.mismo.nivel}
#   }
#   \glosses{2.
#     \gloss{allá.perpendicular.al.río}
#   }
#
# \entry{
# \headword{mɨɨ́sɨɨya}
#   \glosses{
#     \gloss{sacha.ajo}
#   }
#
# \entry{
# \headword{jiki}
#   \glosses{1.
#     \gloss{mandar.hacer}
#   }
#   \glosses{2.
#     \gloss{mandar}
#   }
#
# \entry{
# \headword{tiimúuni}
#   \glosses{
#     \gloss{echar.quilla}
#   }
#
# \entry{
# \headword{tarakɨɨtíini}
#   \glosses{
#     \gloss{tratar.de.dejado}
#   }
#
# \entry{
# \headword{-sa}
#   \glosses{
#     \gloss{NOMZ:OBJ}
#   }
#
# \entry{
# \headword{ruukaasíini}
#   \glosses{
#     \gloss{rogar}
#   }
#
# \entry{
# \headword{amusíini}
#   \glosses{
#     \gloss{cometer.incesto}
#   }
#
# \entry{
# \headword{tipi}
#   \glosses{
#     \gloss{be.stuck}
#   }
#
# \entry{
# \headword{japakɨ́ɨya}
#   \glosses{
#     \gloss{avispa.pl}
#   }
#
# \entry{
# \headword{naanakíkaaku}
#   \glosses{
#   }
#
# \entry{
# \headword{aramituu}
#   \glosses{
#     \gloss{almidón}
#   }
#
# \entry{
# \headword{kumi}
#   \glosses{
#     \gloss{crecer}
#   }
#
# \entry{
# \headword{mɨtiiya}
#   \glosses{
#     \gloss{taricaya.pl}
#   }
#
# \entry{
# \headword{fundaasíini}
#   \glosses{
#     \gloss{fundaásíi}
#   }
#
# \entry{
# \headword{tipaakayúumu}
#   \glosses{
#     \gloss{quebrada.turbia}
#   }
#
# \entry{
# \headword{kámiiyɨ}
#   \glosses{1.
#     \gloss{cogollo.de.chambira.reventado}
#   }
#   \glosses{2.
#     \gloss{soga.tipo}
#   }
#
# \entry{
# \headword{iíkwa míini}
#   \glosses{
#     \gloss{mentira. PL: iíkwa míinika}
#   }
#
# \entry{
# \headword{ijirákana}
#   \glosses{
#     \gloss{palo.de.yuca.cortado}
#   }
#
# \entry{
# \headword{takɨtɨtɨ́ɨni}
#   \glosses{
#     \gloss{dar la vuelta o dar vueltas, por ejemplo un grupo de personas dando vueltas y cantando. Raíz: takɨtɨ́tɨɨ-}
#   }
#
# \entry{
# \headword{=kari}
#   \glosses{
#     \gloss{TIEMPO}
#   }
#
# \entry{
# \headword{iipɨ́kana}
#   \glosses{
#     \gloss{coto.rumo}
#   }
#
# \entry{
# \headword{siyɨɨkɨ́ɨni}
#   \glosses{
#     \gloss{escurecer.lluvia}
#   }
#
# \entry{
# \headword{iímɨtáani}
#   \glosses{
#     \gloss{sacar.hoja}
#   }
#
# \entry{
# \headword{jaati}
#   \glosses{
#   }
#
# \entry{
# \headword{paati}
#   \glosses{
#     \gloss{tío.paterno}
#   }
#
# \entry{
# \headword{takijápɨɨki}
#   \glosses{
#     \gloss{cortos o bajos, hablando de seres animados}
#   }
#
# \entry{
# \headword{isakúuni}
#   \glosses{
#     \gloss{ir.por.un.costado}
#   }
#
# \entry{
# \headword{akasɨyuwa}
#   \glosses{
#     \gloss{macana.esp.pl}
#   }
#
# \entry{
# \headword{saakaaya}
#   \glosses{
#     \gloss{algunas cosas o todas cosas, en general, sin especificar cuáles cosas}
#   }
#
# \entry{
# \headword{aníini}
#   \glosses{
#     \gloss{llover, siempre hablando de: aasi. Raíz: áni-}
#   }
#
# \entry{
# \headword{pɨɨ́rika}
#   \glosses{
#     \gloss{ nosotros.incl.no.más}
#   }
#
# \entry{
# \headword{kámiji}
#   \glosses{
#     \gloss{desde río arriba}
#   }
#
# \entry{
# \headword{iyuutɨ́ɨni}
#   \glosses{
#     \gloss{hacer.oladas}
#   }
#
# \entry{
# \headword{nakújumɨ}
#   \glosses{
#     \gloss{bijao}
#   }
#
# \entry{
# \headword{jɨɨ́tikari}
#   \glosses{
#     \gloss{cuántos tiempos, para un tiempo indefinido}
#   }
#
# \entry{
# \headword{táaja}
#   \glosses{1.
#     \gloss{astilla}
#   }
#   \glosses{2.
#     \gloss{cuerno}
#   }
#
# \entry{
# \headword{=kiyaajaa}
#   \glosses{
#     \gloss{NRWR.PREPAUS}
#   }
#
# \entry{
# \headword{karaákiya}
#   \glosses{
#     \gloss{oloroso, especialmente el olor agradable de grasa o aceite en la candela}
#   }
#
# \entry{
# \headword{iíyaakɨya}
#   \glosses{
#     \gloss{canto}
#   }
#
# \entry{
# \headword{iniyaasi}
#   \glosses{
#     \gloss{olla.de.arcilla}
#   }
#
# \entry{
# \headword{saakaa}
#   \glosses{
#     \gloss{alguna cosa, sin especificar qué es; también lo llamamos: pronombre indefinido}
#   }
#
# \entry{
# \headword{nombre.personal}
#   \glosses{
#     \gloss{nombre.personal}
#   }
#
# \entry{
# \headword{apiikíini}
#   \glosses{
#     \gloss{colgar.(largo)}
#   }
#
# \entry{
# \headword{nikisáani}
#   \glosses{
#     \gloss{carácter}
#   }
#
# \entry{
# \headword{tíwaku}
#   \glosses{
#     \gloss{en o a varios sitios}
#   }
#
# \entry{
# \headword{puruujuutáani}
#   \glosses{1.
#     \gloss{tener.varias.bolas}
#   }
#   \glosses{2.
#     \gloss{abultar}
#   }
#
# \entry{
# \headword{taama miíniika}
#   \glosses{
#     \gloss{apenas}
#   }
#
# \entry{
# \headword{amakɨ́ɨra}
#   \glosses{
#   }
#
# \entry{
# \headword{mɨtáani}
#   \glosses{
#     \gloss{remove.leaves}
#   }
#
# \entry{
# \headword{minákana}
#   \glosses{
#     \gloss{planta.de.yuca}
#   }
#
# \entry{
# \headword{estudiásíini}
#   \glosses{
#     \gloss{estudiar}
#   }
#
# \entry{
# \headword{náana párɨɨna}
#   \glosses{
#     \gloss{plano.de.palo}
#   }
#
# \entry{
# \headword{samáraatɨ́ɨni}
#   \glosses{
#     \gloss{descansar}
#   }
#
# \entry{
# \headword{kukúuni}
#   \glosses{
#     \gloss{chocar contra. Lo chocado lleva: -jina. Raíz: kuku-, kuki-}
#   }
#
# \entry{
# \headword{imáani}
#   \glosses{
#     \gloss{tener.enfermedad}
#   }
#
# \entry{
# \headword{-kiáaja}
#   \glosses{
#   }
#
# \entry{
# \headword{mɨyaara aniaásiija}
#   \glosses{
#     \gloss{cubierto.de.lanza}
#   }
#
# \entry{
# \headword{kasiratáani}
#   \glosses{
#     \gloss{picar.w/lanza}
#   }
#
# \entry{
# \headword{ánasa}
#   \glosses{1.
#     \gloss{rabiosamente, hablando de personas}
#   }
#   \glosses{2.
#     \gloss{fuerte, hablando del sol}
#   }
#
# \entry{
# \headword{=akájinaku}
#   \glosses{
#   }
#
# \entry{
# \headword{mɨyíkɨ}
#   \glosses{
#     \gloss{volver}
#   }
#
# \entry{
# \headword{muusíira}
#   \glosses{
#     \gloss{mochila}
#   }
#
# \entry{
# \headword{makɨ́rajina}
#   \glosses{
#     \gloss{sitio.de.tambo}
#   }
#
# \entry{
# \headword{sinakuka}
#   \glosses{
#     \gloss{shingo.pl}
#   }
#
# \entry{
# \headword{jarɨ́ɨni}
#   \glosses{
#     \gloss{desgranarse. Raíz: jaatɨ-, jaati-}
#   }
#
# \entry{
# \headword{sikiitáani}
#   \glosses{
#     \gloss{meter.en.líquido}
#   }
#
# \entry{
# \headword{-kiaakɨ́na}
#   \glosses{
#     \gloss{PFV.DPST.REP}
#   }
#
# \entry{
# \headword{íiya kájapaa}
#   \glosses{
#     \gloss{en.verdad}
#   }
#
# \entry{
# \headword{=jaa}
#   \glosses{
#     \gloss{IRR.EXTR}
#   }
#
# \entry{
# \headword{máaya}
#   \glosses{
#     \gloss{"hija" o "hijo" -- palabra usada par llamar la atención de una hija o un hijo. PL: mɨrajaárika}
#   }
#
# \entry{
# \headword{NON.LEX}
#   \glosses{
#     \gloss{NON.LEX}
#   }
#
# \entry{
# \headword{namíkiika}
#   \glosses{1.
#     \gloss{derecho y recto hacia abajo, hablando de la posición de algo}
#   }
#   \glosses{2.
#     \gloss{la manera de irse río abajo directamente y sin parar}
#   }
#   \glosses{3.
#     \gloss{derecho y recto con una posición hacia abajo o hacia río abajo}
#   }
#   \glosses{4.
#     \gloss{estar puesto en un solo envase}
#   }
#
# \entry{
# \headword{Siaankanáaku}
#   \glosses{
#     \gloss{personaje.histórico}
#   }
#
# \entry{
# \headword{-ø}
#   \glosses{
#     \gloss{PFV}
#   }
#
# \entry{
# \headword{apiyɨɨ́naa}
#   \glosses{
#     \gloss{palo.chaflaneado.pl}
#   }
#
# \entry{
# \headword{sapatiwa}
#   \glosses{
#     \gloss{zúngaro.negro.pl}
#   }
#
# \entry{
# \headword{naajáaja}
#   \glosses{
#     \gloss{también}
#   }
#
# \entry{
# \headword{maasia iwíini}
#   \glosses{
#     \gloss{demorar. Raíz: maasia iíki-}
#   }
#
# \entry{
# \headword{jɨɨ́taraa}
#   \glosses{
#     \gloss{manera.INDEF}
#   }
#
# \entry{
# \headword{íniiki}
#   \glosses{
#     \gloss{bobona}
#   }
#
# \entry{
# \headword{kuwaniijɨ́ɨni}
#   \glosses{
#     \gloss{asar.yuca.con.cascar}
#   }
#
# \entry{
# \headword{iwarajáani}
#   \glosses{
#     \gloss{terminar}
#   }
#
# \entry{
# \headword{tasíina}
#   \glosses{
#     \gloss{palo.esp}
#   }
#
# \entry{
# \headword{aasamúuwa}
#   \glosses{
#     \gloss{quebrada.pl}
#   }
#
# \entry{
# \headword{naári}
#   \glosses{
#     \gloss{pararse}
#   }
#
# \entry{
# \headword{DELETED}
#   \glosses{
#   }
#
# \entry{
# \headword{siisíija}
#   \glosses{
#     \gloss{abuelo o bisabuelo. PL: siisíijawaaka}
#   }
#
# \entry{
# \headword{tɨɨ́yuukwáani}
#   \glosses{
#     \gloss{tipo de carpintero, especie de ave. PL: tɨɨ́yuukwaánika}
#   }
#
# \entry{
# \headword{jataana}
#   \glosses{
#     \gloss{ADJVZR}
#   }
#
# \entry{
# \headword{maayaasíini}
#   \glosses{1.
#     \gloss{fiesta. PL: maayaasiínika}
#   }
#   \glosses{2.
#     \gloss{baile o estilo de baile. PL: maayaasiínika}
#   }
#
# \entry{
# \headword{inisíkini}
#   \glosses{
#     \gloss{cunchi.esp}
#   }
#
# \entry{
# \headword{naárika}
#   \glosses{
#     \gloss{asi.mismo.EXCL}
#   }
#
# \entry{
# \headword{natánaka}
#   \glosses{
#     \gloss{planta.sembrado.pl}
#   }
#
# \entry{
# \headword{-maji}
#   \glosses{
#     \gloss{PROX}
#   }
#
# \entry{
# \headword{nakarɨ́ɨni}
#   \glosses{
#     \gloss{estar.en.punto.de}
#   }
#
# \entry{
# \headword{kuukisaákari}
#   \glosses{1.
#     \gloss{quizás}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{tiírakuma}
#   \glosses{
#     \gloss{hacer.yendo}
#   }
#
# \entry{
# \headword{iyákumasíini}
#   \glosses{
#     \gloss{apurarse}
#   }
#
# \entry{
# \headword{ijiráani}
#   \glosses{
#     \gloss{latir}
#   }
#
# \entry{
# \headword{iniyɨ}
#   \glosses{
#     \gloss{soga torcida, especialmente la de chambira. PL: iniyɨka}
#   }
#
# \entry{
# \headword{takɨtɨ́ɨni}
#   \glosses{
#     \gloss{madre.de.la.yuca}
#   }
#
# \entry{
# \headword{káani}
#   \glosses{
#     \gloss{espíritu.compañero}
#   }
#
# \entry{
# \headword{sipɨ́ɨni}
#   \glosses{
#     \gloss{dar de mamar. Raíz: sipɨɨ-}
#   }
#
# \entry{
# \headword{=jinaji}
#   \glosses{
#     \gloss{COMPAR}
#   }
#
# \entry{
# \headword{ruutiaákɨɨya}
#   \glosses{
#     \gloss{cotolo.esp.pl}
#   }
#
# \entry{
# \headword{tarapíisi}
#   \glosses{
#     \gloss{trapiche}
#   }
#
# \entry{
# \headword{kwáartɨya}
#   \glosses{
#     \gloss{guardia}
#   }
#
# \entry{
# \headword{-ki}
#   \glosses{
#     \gloss{area}
#   }
#
# \entry{
# \headword{karɨɨ́ji}
#   \glosses{
#     \gloss{tener.sed}
#   }
#
# \entry{
# \headword{paaki}
#   \glosses{
#     \gloss{estacarse}
#   }
#
# \entry{
# \headword{apɨya}
#   \glosses{
#     \gloss{cinturón. PL: apɨyaka}
#   }
#
# \entry{
# \headword{nɨrímɨɨna sawija}
#   \glosses{
#     \gloss{piedra.relámpago}
#   }
#
# \entry{
# \headword{ijáwɨɨti}
#   \glosses{
#     \gloss{casa con techo de irapay. PL: ijáwɨɨtiwa}
#   }
#
# \entry{
# \headword{normaliisíini}
#   \glosses{
#     \gloss{normalizar}
#   }
#
# \entry{
# \headword{jɨɨ́taraata}
#   \glosses{
#     \gloss{como o ya que -- palabra que conecta dos enunciados}
#   }
#
# \entry{
# \headword{yaasiki}
#   \glosses{
#     \gloss{la parte más tarde de la noche}
#   }
#
# \entry{
# \headword{jiitáani}
#   \glosses{
#     \gloss{crecer.río}
#   }
#
# \entry{
# \headword{pisiáaniíya}
#   \glosses{
#     \gloss{pichanilla}
#   }
#
# \entry{
# \headword{taasiijáani}
#   \glosses{1.
#     \gloss{malograr una dieta, hablando de la dieta de una purga . Raíz: taasiíja-}
#   }
#   \glosses{2.
#     \gloss{malograr un aparato o máquina. Raíz: taasiíja-}
#   }
#
# \entry{
# \headword{ijirɨ́ɨni}
#   \glosses{
#     \gloss{estar sentado. Raíz: ijiítɨ-}
#   }
#
# \entry{
# \headword{atáani}
#   \glosses{
#     \gloss{palpitar}
#   }
#
# \entry{
# \headword{júnɨɨna iríini}
#   \glosses{
#     \gloss{respirar. Raíz: júnɨɨna íri-}
#   }
#
# \entry{
# \headword{iyikúura}
#   \glosses{
#     \gloss{defensa}
#   }
#
# \entry{
# \headword{iniyana}
#   \glosses{
#     \gloss{puente. PL: iniiyaka, iniyanaka}
#   }
#
# \entry{
# \headword{kamíkuku}
#   \glosses{1.
#     \gloss{yendo.río.arriba}
#   }
#   \glosses{2.
#     \gloss{yendo.por.arriba}
#   }
#
# \entry{
# \headword{púruutáani}
#   \glosses{
#     \gloss{hacer.bola}
#   }
#
# \entry{
# \headword{rikúti}
#   \glosses{1.
#     \gloss{degajarse}
#   }
#   \glosses{2.
#     \gloss{romperse.rendija}
#   }
#
# \entry{
# \headword{kájapaki}
#   \glosses{
#     \gloss{felizmente}
#   }
#
# \entry{
# \headword{mátaka}
#   \glosses{
#     \gloss{cumba}
#   }
#
# \entry{
# \headword{naa=}
#   \glosses{1.
#     \gloss{otra.vez}
#   }
#   \glosses{2.
#     \gloss{también}
#   }
#   \glosses{3.
#     \gloss{de.la.misma.manera}
#   }
#
# \entry{
# \headword{ka=aatiáana}
#   \glosses{1.
#     \gloss{cntf2}
#   }
#   \glosses{2.
#     \gloss{POLITE}
#   }
#   \glosses{3.
#     \gloss{no.sería.capáz}
#   }
#
# \entry{
# \headword{imakiijatáani}
#   \glosses{
#     \gloss{sacar.barro}
#   }
#
# \entry{
# \headword{muuti jiniiri}
#   \glosses{
#     \gloss{estilo de tejer crisneja de irapay que se parece como el camino del añuje. PL: muuti jiniiriwa, muuti jiniirika}
#   }
#
# \entry{
# \headword{kumáani}
#   \glosses{
#     \gloss{Dios. PL: no hay}
#   }
#
# \entry{
# \headword{uraásii}
#   \glosses{
#     \gloss{orar}
#   }
#
# \entry{
# \headword{siiturúkiaakɨ}
#   \glosses{
#   }
#
# \entry{
# \headword{kiipɨ}
#   \glosses{
#     \gloss{esos oe sas, hablando de seres animados cerca del oyente}
#   }
#
# \entry{
# \headword{tuujiitáani}
#   \glosses{1.
#     \gloss{escuchar para ubicar algo, por ejemplo un animal.  Raíz: tuujiíta-}
#   }
#   \glosses{2.
#     \gloss{escuchar escondido. Raíz: tujiíta-}
#   }
#
# \entry{
# \headword{siikiyúuwa}
#   \glosses{
#     \gloss{avispa.esp.pl}
#   }
#
# \entry{
# \headword{araa}
#   \glosses{
#     \gloss{"¡ves!"}
#   }
#
# \entry{
# \headword{=iíkwaji}
#   \glosses{
#     \gloss{PART}
#   }
#
# \entry{
# \headword{tikíini}
#   \glosses{1.
#     \gloss{hacer.entrar}
#   }
#   \glosses{2.
#     \gloss{sumir}
#   }
#
# \entry{
# \headword{íjiikáani}
#   \glosses{
#     \gloss{quejarse con dolor. Raíz: íjiika-}
#   }
#
# \entry{
# \headword{jíkiwa}
#   \glosses{
#     \gloss{comején.esp.pl}
#   }
#
# \entry{
# \headword{wiituu}
#   \glosses{
#     \gloss{bidón}
#   }
#
# \entry{
# \headword{kɨɨ́raki iwíini}
#   \glosses{
#     \gloss{menstruar}
#   }
#
# \entry{
# \headword{sinákati}
#   \glosses{
#     \gloss{desnudarse}
#   }
#
# \entry{
# \headword{sipɨɨya}
#   \glosses{
#     \gloss{seno.pl}
#   }
#
# \entry{
# \headword{ajapaka}
#   \glosses{
#     \gloss{avispa en general, hablando del insecto o su nido. PL: ajapakɨ́ɨya, ajapakaka}
#   }
#
# \entry{
# \headword{iyɨɨtáani}
#   \glosses{
#     \gloss{cantear.chacra}
#   }
#
# \entry{
# \headword{atitíini}
#   \glosses{
#     \gloss{empezar}
#   }
#
# \entry{
# \headword{tuwiina}
#   \glosses{
#     \gloss{sinamillo, especie de palmera}
#   }
#
# \entry{
# \headword{iíwɨɨti}
#   \glosses{
#     \gloss{planta.esp}
#   }
#
# \entry{
# \headword{tíini}
#   \glosses{1.
#     \gloss{apegarse o pegarse, dicho de cosas anchas. Raíz: tii-}
#   }
#   \glosses{2.
#     \gloss{estar templado, hablando de hamacas. Raíz: tii-}
#   }
#   \glosses{3.
#     \gloss{estar pegado en un palo, hablando de nidos. Raíz: tii-}
#   }
#
# \entry{
# \headword{=iríkumaji}
#   \glosses{
#     \gloss{al.costado.de}
#   }
#
# \entry{
# \headword{nijápɨɨki}
#   \glosses{
#     \gloss{ellos.no.mas}
#   }
#
# \entry{
# \headword{sirikuutáani}
#   \glosses{
#   }
#
# \entry{
# \headword{tiínaaja}
#   \glosses{
#     \gloss{tinaja}
#   }
#
# \entry{
# \headword{siíriija}
#   \glosses{
#     \gloss{abuela o bisabuela. PL: siíriijawaaka}
#   }
#
# \entry{
# \headword{kiírika}
#   \glosses{
#     \gloss{yo no más o yo solito}
#   }
#
# \entry{
# \headword{imatɨ́niikíini}
#   \glosses{
#     \gloss{contradecir}
#   }
#
# \entry{
# \headword{kíyɨɨtaníini}
#   \glosses{
#     \gloss{hacer.vacío}
#   }
#
# \entry{
# \headword{sapatina}
#   \glosses{
#     \gloss{negro}
#   }
#
# \entry{
# \headword{Sanantonio}
#   \glosses{
#     \gloss{San Antonio}
#   }
#
# \entry{
# \headword{valiisíini}
#   \glosses{
#     \gloss{valer}
#   }
#
# \entry{
# \headword{tatɨɨ́kujina}
#   \glosses{
#     \gloss{tarima o piso emponado. PL: tatɨɨkukajina}
#   }
#
# \entry{
# \headword{tatɨɨkuúkujina}
#   \glosses{
#     \gloss{emponado}
#   }
#
# \entry{
# \headword{jaátaraa}
#   \glosses{1.
#     \gloss{cómo}
#   }
#   \glosses{2.
#     \gloss{como}
#   }
#
# \entry{
# \headword{íindiu}
#   \glosses{
#     \gloss{indio}
#   }
#
# \entry{
# \headword{iyújaakáani}
#   \glosses{
#     \gloss{tratar.de.haragán}
#   }
#
# \entry{
# \headword{amaakúuja}
#   \glosses{1.
#     \gloss{plataforma para cazar, usualmente construida en las ramas de un árbol con muchos frutos maduros que atraen mitayo. PL: amaakúujaka}
#   }
#   \glosses{2.
#     \gloss{armazón de casa. PL: amaakúujaka}
#   }
#
# \entry{
# \headword{iipɨɨ aríyasi}
#   \glosses{
#     \gloss{pijuayo.var}
#   }
#
# \entry{
# \headword{asɨɨ́ti}
#   \glosses{
#     \gloss{resbalarse}
#   }
#
# \entry{
# \headword{kaasi táraati}
#   \glosses{
#     \gloss{pashaco.esp.}
#   }
#
# \entry{
# \headword{aríini}
#   \glosses{
#     \gloss{querer.hacer}
#   }
#
# \entry{
# \headword{saráani}
#   \glosses{
#     \gloss{hacer sumir una canoa. Raíz: saáta-}
#   }
#
# \entry{
# \headword{jaáki}
#   \glosses{
#     \gloss{mermar}
#   }
#
# \entry{
# \headword{iísiki}
#   \glosses{1.
#     \gloss{desmayar}
#   }
#   \glosses{2.
#     \gloss{sufrir.ataque.de.gota.corral}
#   }
#
# \entry{
# \headword{Ikíitu}
#   \glosses{
#     \gloss{Iquitos}
#   }
#
# \entry{
# \headword{tákaama}
#   \glosses{
#     \gloss{vacío}
#   }
#
# \entry{
# \headword{=tɨ}
#   \glosses{
#     \gloss{INFER}
#   }
#
# \entry{
# \headword{apirakiitáani}
#   \glosses{
#     \gloss{colgar(brazos/piernas)}
#   }
#
# \entry{
# \headword{jamɨ́kiji}
#   \glosses{
#     \gloss{mano y brazo izquierda. PL: jamɨ́kijika}
#   }
#
# \entry{
# \headword{purútaari}
#   \glosses{
#     \gloss{yulilla}
#   }
#
# \entry{
# \headword{takuutaníini}
#   \glosses{
#     \gloss{hacer parar}
#   }
#
# \entry{
# \headword{irisíini}
#   \glosses{
#     \gloss{endurarse}
#   }
#
# \entry{
# \headword{tatɨɨwɨyajina}
#   \glosses{
#     \gloss{ponal}
#   }
#
# \entry{
# \headword{nɨ́raaka}
#   \glosses{
#     \gloss{coto.3P}
#   }
#
# \entry{
# \headword{Yaaswaá}
#   \glosses{
#     \gloss{"Jazz Band"}
#   }
#
# \entry{
# \headword{operaasíini}
#   \glosses{
#     \gloss{operar}
#   }
#
# \entry{
# \headword{saamiya}
#   \glosses{
#     \gloss{abeja.pl}
#   }
#
# \entry{
# \headword{kamijiíraji}
#   \glosses{1.
#     \gloss{allá.arriba}
#   }
#   \glosses{2.
#     \gloss{allá.río.arriba}
#   }
#   \glosses{3.
#     \gloss{afuera}
#   }
#
# \entry{
# \headword{riimuutáani}
#   \glosses{
#   }
#
# \entry{
# \headword{siinakíriisi}
#   \glosses{
#     \gloss{líder.de.huangana}
#   }
#
# \entry{
# \headword{tiiniwiitáani}
#   \glosses{
#     \gloss{seguir varias veces. Raíz: tiiniwiíta-}
#   }
#
# \entry{
# \headword{iyúuna}
#   \glosses{
#     \gloss{olada. PL: iyúunaka}
#   }
#
# \entry{
# \headword{-jiita}
#   \glosses{
#     \gloss{PROX}
#   }
#
# \entry{
# \headword{aakuurtiuu}
#   \glosses{
#     \gloss{acordión}
#   }
#
# \entry{
# \headword{pakiitɨ́ɨni}
#   \glosses{1.
#     \gloss{topar.costados}
#   }
#   \glosses{2.
#     \gloss{cerrarse}
#   }
#
# \entry{
# \headword{waátina}
#   \glosses{
#     \gloss{tener el rico olor de la carne ahumada}
#   }
#
# \entry{
# \headword{tampúura}
#   \glosses{
#     \gloss{tambor}
#   }
#
# \entry{
# \headword{titáani}
#   \glosses{
#     \gloss{coger.pijuayo}
#   }
#
# \entry{
# \headword{makɨ́ɨni}
#   \glosses{
#     \gloss{soñar. Raíz: makɨ-, maki-}
#   }
#
# \entry{
# \headword{aátamajátiisana}
#   \glosses{
#     \gloss{hermana finada de mujer. PL: átamajátiisanawaaka}
#   }
#
# \entry{
# \headword{muusajákwaapɨ}
#   \glosses{
#     \gloss{suri.de.ungurahui.pl}
#   }
#
# \entry{
# \headword{apiyɨɨnɨ́ɨni}
#   \glosses{
#     \gloss{hacer.camino.cortando.en.alto}
#   }
#
# \entry{
# \headword{=jaa}
#   \glosses{
#     \gloss{AFIRM}
#   }
#
# \entry{
# \headword{maamáaja}
#   \glosses{
#     \gloss{madre}
#   }
#
# \entry{
# \headword{Niíyaamu}
#   \glosses{
#     \gloss{quebrada}
#   }
#
# \entry{
# \headword{anija}
#   \glosses{
#   }
#
# \entry{
# \headword{Paantiyuu}
#   \glosses{
#     \gloss{panteón}
#   }
#
# \entry{
# \headword{kuúti}
#   \glosses{
#     \gloss{romperse}
#   }
#
# \entry{
# \headword{kuruja}
#   \glosses{
#     \gloss{cera de abeja. PL: kurujaka}
#   }
#
# \entry{
# \headword{níiya jíritiku}
#   \glosses{
#     \gloss{medio.dia}
#   }
#
# \entry{
# \headword{maayaarika}
#   \glosses{1.
#     \gloss{niño o niña pequeño. PL: mɨrajaarika}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{isakijiíraji}
#   \glosses{
#     \gloss{otro.lado}
#   }
#
# \entry{
# \headword{salvaásíini}
#   \glosses{
#     \gloss{salvar}
#   }
#
# \entry{
# \headword{taasíita siirɨ}
#   \glosses{
#     \gloss{lagarto.blanco}
#   }
#
# \entry{
# \headword{aakaayɨ}
#   \glosses{
#     \gloss{vaca.marina}
#   }
#
# \entry{
# \headword{sasɨɨtáani}
#   \glosses{
#     \gloss{calmar.dolor}
#   }
#
# \entry{
# \headword{jɨɨ́tirimi}
#   \glosses{1.
#     \gloss{cuántos.inanimados}
#   }
#   \glosses{2.
#     \gloss{algunos.inanimados}
#   }
#   \glosses{3.
#     \gloss{cuantos.inanimados}
#   }
#
# \entry{
# \headword{íniijaa}
#   \glosses{1.
#     \gloss{huayo.pl}
#   }
#   \glosses{2.
#     \gloss{semillas}
#   }
#
# \entry{
# \headword{sɨrika}
#   \glosses{
#     \gloss{enfermedad.de.la.piel}
#   }
#
# \entry{
# \headword{sakina isíiku}
#   \glosses{
#   }
#
# \entry{
# \headword{atiíyaajaa}
#   \glosses{
#     \gloss{todavia}
#   }
#
# \entry{
# \headword{iyakuuraanɨ́ɨni}
#   \glosses{
#     \gloss{costar. Raíz: iyakuuraánɨɨ-}
#   }
#
# \entry{
# \headword{nawɨ́nɨɨna}
#   \glosses{
#     \gloss{birote}
#   }
#
# \entry{
# \headword{agradesiisíini}
#   \glosses{
#     \gloss{agradecer}
#   }
#
# \entry{
# \headword{itiyɨ}
#   \glosses{
#     \gloss{prepucio}
#   }
#
# \entry{
# \headword{namijiíraji}
#   \glosses{1.
#     \gloss{allá río abajo, hablando de la parte río abajo de un espacio delimitado}
#   }
#   \glosses{2.
#     \gloss{allá abajo, hablando de la parte inferior de un espacio delimitado}
#   }
#
# \entry{
# \headword{kaajiya}
#   \glosses{
#     \gloss{crías o mascotas, forma plural.}
#   }
#
# \entry{
# \headword{jiipuutáani}
#   \glosses{
#     \gloss{dar mucha comida o bebida, dando una porción más grande de lo dado a otros. Raíz: jiipuúta-}
#   }
#
# \entry{
# \headword{ípuusi}
#   \glosses{
#     \gloss{panza.de.pescado}
#   }
#
# \entry{
# \headword{táaja}
#   \glosses{
#     \gloss{COP.PREPAUS}
#   }
#
# \entry{
# \headword{-kami}
#   \glosses{
#     \gloss{part.pl.inan}
#   }
#
# \entry{
# \headword{taasuu}
#   \glosses{
#     \gloss{tazón (del castellano)}
#   }
#
# \entry{
# \headword{risistiisiíini}
#   \glosses{
#     \gloss{resistir}
#   }
#
# \entry{
# \headword{súruukutáana}
#   \glosses{
#     \gloss{sacharuna.perdiz}
#   }
#
# \entry{
# \headword{preocupaasíini}
#   \glosses{
#     \gloss{preocuparse}
#   }
#
# \entry{
# \headword{riimuutɨ́ɨni}
#   \glosses{
#   }
#
# \entry{
# \headword{iyáaki}
#   \glosses{
#     \gloss{este.tamaño}
#   }
#
# \entry{
# \headword{saakɨɨníini}
#   \glosses{
#     \gloss{contar un cuento a alguien. Raíz: saakɨɨ́nii-}
#   }
#
# \entry{
# \headword{iyikuuraanɨ́ɨni}
#   \glosses{
#     \gloss{costar}
#   }
#
# \entry{
# \headword{tami}
#   \glosses{
#     \gloss{busilar}
#   }
#
# \entry{
# \headword{imáani}
#   \glosses{
#     \gloss{ganar}
#   }
#
# \entry{
# \headword{-kúu}
#   \glosses{
#     \gloss{PLACT.huayo}
#   }
#
# \entry{
# \headword{raatisami}
#   \glosses{
#   }
#
# \entry{
# \headword{kinaárika}
#   \glosses{
#     \gloss{ustedes no más}
#   }
#
# \entry{
# \headword{saapi jimɨɨti}
#   \glosses{
#     \gloss{champiñon.comestible}
#   }
#
# \entry{
# \headword{-kumaji}
#   \glosses{
#     \gloss{sitio.de}
#   }
#
# \entry{
# \headword{paáriwa}
#   \glosses{
#     \gloss{pucacunga}
#   }
#
# \entry{
# \headword{kiitaásii}
#   \glosses{
#     \gloss{quitar}
#   }
#
# \entry{
# \headword{aamuutáani}
#   \glosses{
#     \gloss{golpear.ala}
#   }
#
# \entry{
# \headword{makitáani}
#   \glosses{1.
#     \gloss{cosechar yuca verde. Raíz: makita-}
#   }
#   \glosses{2.
#     \gloss{cosechar frutos verdes. Raíz: makita-}
#   }
#
# \entry{
# \headword{kaarnawáara}
#   \glosses{
#     \gloss{Carnaval}
#   }
#
# \entry{
# \headword{muutíina}
#   \glosses{
#     \gloss{planta.medicinal}
#   }
#
# \entry{
# \headword{=kiyaa}
#   \glosses{
#     \gloss{NRWR}
#   }
#
# \entry{
# \headword{muúsaniika}
#   \glosses{
#     \gloss{nido.de.isula}
#   }
#
# \entry{
# \headword{iríkiti}
#   \glosses{
#     \gloss{romperse.capullo}
#   }
#
# \entry{
# \headword{kuupáara}
#   \glosses{
#     \gloss{copal}
#   }
#
# \entry{
# \headword{akuumíini}
#   \glosses{
#     \gloss{tener cuñado o suegro, hablando de los hombres. Raíz: akuúmii-}
#   }
#
# \entry{
# \headword{iyaákari}
#   \glosses{
#     \gloss{en ese momento}
#   }
#
# \entry{
# \headword{karikuma}
#   \glosses{
#     \gloss{debajo.de}
#   }
#
# \entry{
# \headword{aráaku}
#   \glosses{
#     \gloss{tronera o nido en la tierra, por ejemplo del majás. PL: araákuka}
#   }
#
# \entry{
# \headword{iwatáani}
#   \glosses{1.
#     \gloss{llevar a una persona a propósito. Raíz: iwáta-}
#   }
#   \glosses{2.
#     \gloss{llevar una cosa. Raíz: iwáta-}
#   }
#
# \entry{
# \headword{nɨ́siiya}
#   \glosses{
#     \gloss{carbón.pl}
#   }
#
# \entry{
# \headword{kumuuniikaásii}
#   \glosses{
#     \gloss{comunicar}
#   }
#
# \entry{
# \headword{paisáana}
#   \glosses{
#     \gloss{paisano}
#   }
#
# \entry{
# \headword{muunisiuu}
#   \glosses{
#     \gloss{munición}
#   }
#
# \entry{
# \headword{súunsu}
#   \glosses{
#     \gloss{zonzo}
#   }
#
# \entry{
# \headword{waakrapúuna}
#   \glosses{
#     \gloss{huacrapona}
#   }
#
# \entry{
# \headword{nakuta}
#   \glosses{
#     \gloss{palmera.esp}
#   }
#
# \entry{
# \headword{-kíina}
#   \glosses{
#     \gloss{CL:huayo.con.punta }
#   }
#
# \entry{
# \headword{jɨɨ́tiripɨ}
#   \glosses{1.
#     \gloss{cuántos.animados}
#   }
#   \glosses{2.
#     \gloss{algunos.animados}
#   }
#   \glosses{3.
#     \gloss{cuantos.animates}
#   }
#
# \entry{
# \headword{nɨ́mɨɨjɨɨ́jina}
#   \glosses{
#   }
#
# \entry{
# \headword{waantíija}
#   \glosses{
#     \gloss{bandeja}
#   }
#
# \entry{
# \headword{tɨ́wɨja}
#   \glosses{1.
#     \gloss{astilla.de.pez}
#   }
#   \glosses{2.
#     \gloss{cuerno}
#   }
#
# \entry{
# \headword{rɨkɨnaaja}
#   \glosses{
#     \gloss{palmera.sp}
#   }
#
# \entry{
# \headword{amáriyaana}
#   \glosses{
#   }
#
# \entry{
# \headword{tarakɨɨ́ta míini}
#   \glosses{
#     \gloss{hacerse cobarde. Raíz: tarakɨɨ́ta mii-}
#   }
#
# \entry{
# \headword{atɨɨtɨ́ɨni}
#   \glosses{1.
#     \gloss{templar}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{yaawɨ́ɨni ɨɨ́jakɨya}
#   \glosses{
#   }
#
# \entry{
# \headword{taraasíini}
#   \glosses{
#     \gloss{huequear.semilla}
#   }
#
# \entry{
# \headword{-kuma}
#   \glosses{
#     \gloss{PROH}
#   }
#
# \entry{
# \headword{samatɨ́ɨni}
#   \glosses{1.
#     \gloss{desatarse}
#   }
#   \glosses{2.
#     \gloss{destrenzar}
#   }
#
# \entry{
# \headword{sajikiitáani}
#   \glosses{
#     \gloss{cortar varias ramas o quitar las ramas de algo}
#   }
#
# \entry{
# \headword{iimajiíraji}
#   \glosses{
#     \gloss{abajo}
#   }
#
# \entry{
# \headword{-kapɨ}
#   \glosses{
#     \gloss{part.pl.anim}
#   }
#
# \entry{
# \headword{atɨɨtáani}
#   \glosses{
#     \gloss{jalar.de.la.mano}
#   }
#
# \entry{
# \headword{rimútɨ}
#   \glosses{
#     \gloss{disparar(lazo)}
#   }
#
# \entry{
# \headword{tasiina}
#   \glosses{
#     \gloss{sinamillo}
#   }
#
# \entry{
# \headword{nawarɨ́ɨni}
#   \glosses{
#     \gloss{nubes.rojos}
#   }
#
# \entry{
# \headword{iitiírakuma}
#   \glosses{
#     \gloss{por.este.camino}
#   }
#
# \entry{
# \headword{masɨ́yaja iíwaasi}
#   \glosses{
#     \gloss{amarrado.de.cola.de.veranero}
#   }
#
# \entry{
# \headword{suriitáani}
#   \glosses{
#     \gloss{brillar un poco el sol a pesar de estar nublado el cielo. Raíz: suriíta-}
#   }
#
# \entry{
# \headword{pikɨ́ɨni}
#   \glosses{
#     \gloss{malograr.(fermentar)}
#   }
#
# \entry{
# \headword{mɨ́yuujáana}
#   \glosses{
#   }
#
# \entry{
# \headword{kɨɨna}
#   \glosses{
#     \gloss{criminal}
#   }
#
# \entry{
# \headword{tíirajiika}
#   \glosses{
#   }
#
# \entry{
# \headword{jimúkiaaka}
#   \glosses{
#   }
#
# \entry{
# \headword{ijíkiwa}
#   \glosses{
#     \gloss{comején.esp.pl}
#   }
#
# \entry{
# \headword{najaápusuuka}
#   \glosses{
#   }
#
# \entry{
# \headword{muusajákwaa aarɨwati}
#   \glosses{
#     \gloss{tipo de papaso de palmera. PL: muusajákwaa aarɨwatika}
#   }
#
# \entry{
# \headword{karíini}
#   \glosses{
#     \gloss{mirada de un ser. PL: karíinika}
#   }
#
# \entry{
# \headword{anaawaaka}
#   \glosses{
#     \gloss{3pl.PRO.PROM}
#   }
#
# \entry{
# \headword{waarata aamikáaka}
#   \glosses{
#     \gloss{dos días antes o dos días después de hoy, es decir anteayer o pasa mañana. No hay forma plural.}
#   }
#
# \entry{
# \headword{naanaka}
#   \glosses{
#     \gloss{sangre}
#   }
#
# \entry{
# \headword{iyujúuni}
#   \glosses{
#     \gloss{tener pereza. Raíz: iyuúju-, iyuúji-}
#   }
#
# \entry{
# \headword{maatríina}
#   \glosses{
#     \gloss{madrina}
#   }
#
# \entry{
# \headword{ikijɨ́ɨni}
#   \glosses{
#   }
#
# \entry{
# \headword{itɨwɨ́naja}
#   \glosses{
#     \gloss{tizón. PL: itɨwɨ́najaka}
#   }
#
# \entry{
# \headword{sapakaka}
#   \glosses{
#     \gloss{suciedad del cuerpo. PL: uumáata sapakaka}
#   }
#
# \entry{
# \headword{aakuuna}
#   \glosses{
#     \gloss{'primo' -- palabra que usamos para llamarle a nuestro primo o prima}
#   }
#
# \entry{
# \headword{maaráaka}
#   \glosses{
#     \gloss{maraca}
#   }
#
# \entry{
# \headword{irikɨ́ɨni}
#   \glosses{
#     \gloss{arinconarse}
#   }
#
# \entry{
# \headword{kiniku}
#   \glosses{1.
#     \gloss{allí.arriba}
#   }
#   \glosses{2.
#     \gloss{allí.río.arriba}
#   }
#
# \entry{
# \headword{mɨyajáana}
#   \glosses{1.
#     \gloss{caña.brava}
#   }
#   \glosses{2.
#     \gloss{isana}
#   }
#
# \entry{
# \headword{kuusáana}
#   \glosses{
#     \gloss{cocina. Basado en el castellano: cocina. PL: kuusáanaka}
#   }
#
# \entry{
# \headword{irímaatiisana}
#   \glosses{
#     \gloss{hermana finada de hombre. PL: irímaatiisanawaaka}
#   }
#
# \entry{
# \headword{ikija}
#   \glosses{
#     \gloss{tercio de irapay. PL: ikijaka}
#   }
#
# \entry{
# \headword{sakanaa}
#   \glosses{
#     \gloss{carahuasca.pl}
#   }
#
# \entry{
# \headword{jɨyɨɨsíini}
#   \glosses{
#     \gloss{gustarse demasiado o estar obsesionado con algo. Raíz:jɨyɨɨ́si-}
#   }
#
# \entry{
# \headword{turi}
#   \glosses{
#     \gloss{secarse}
#   }
#
# \entry{
# \headword{tiirɨɨ́raata}
#   \glosses{
#     \gloss{más.allá}
#   }
#
# \entry{
# \headword{íyɨ}
#   \glosses{
#     \gloss{puesto}
#   }
#
# \entry{
# \headword{iwárɨɨja}
#   \glosses{
#     \gloss{talludo}
#   }
#
# \entry{
# \headword{tuwɨsɨ́kɨɨya}
#   \glosses{
#   }
#
# \entry{
# \headword{aasíyuu}
#   \glosses{
#     \gloss{llama.lluvia}
#   }
#
# \entry{
# \headword{nɨɨ́tana}
#   \glosses{
#     \gloss{huito}
#   }
#
# \entry{
# \headword{taari}
#   \glosses{
#     \gloss{antes o anteriormente. Otra forma es: taariíyaajaa}
#   }
#
# \entry{
# \headword{papaanúuni}
#   \glosses{
#     \gloss{hacer.hueco}
#   }
#
# \entry{
# \headword{Mɨɨniikáani}
#   \glosses{
#     \gloss{nombre.personal}
#   }
#
# \entry{
# \headword{inflamaasíini}
#   \glosses{
#     \gloss{inflamarse}
#   }
#
# \entry{
# \headword{mɨra}
#   \glosses{
#     \gloss{niños y niñas, forma plural de maaya. Siempre usado en forma poseída, por ejemplo: nu-mɨra}
#   }
#
# \entry{
# \headword{kanɨ́wɨɨja}
#   \glosses{
#     \gloss{cascajo, piedra sedimentaria. PL: kanɨ́wɨɨjaka}
#   }
#
# \entry{
# \headword{kiísi}
#   \glosses{
#     \gloss{enflaquecerse}
#   }
#
# \entry{
# \headword{aajapáaja}
#   \glosses{1.
#     \gloss{aunque}
#   }
#   \glosses{2.
#     \gloss{no se duda}
#   }
#
# \entry{
# \headword{matáani}
#   \glosses{
#     \gloss{sacar.espina}
#   }
#
# \entry{
# \headword{-kɨya}
#   \glosses{
#     \gloss{PL}
#   }
#
# \entry{
# \headword{sinaki}
#   \glosses{
#     \gloss{aplastarse.por.palo}
#   }
#
# \entry{
# \headword{Iísuuja}
#   \glosses{
#     \gloss{personaje.histórico}
#   }
#
# \entry{
# \headword{súruukutáani}
#   \glosses{
#     \gloss{silbar.sacharuna.perdiz}
#   }
#
# \entry{
# \headword{siípakɨya}
#   \glosses{
#     \gloss{lejos.de.otros}
#   }
#
# \entry{
# \headword{aarɨ́ɨni}
#   \glosses{
#     \gloss{pasar o ocurrir algo a alguien. Raíz: aárɨɨ-}
#   }
#
# \entry{
# \headword{aniikiitúuni}
#   \glosses{
#     \gloss{cargar.con.pretina.PLACT}
#   }
#
# \entry{
# \headword{míinka}
#   \glosses{
#     \gloss{minga. Basado en el castellano: minga. PL: míinkaka}
#   }
#
# \entry{
# \headword{irísina}
#   \glosses{
#     \gloss{sabido}
#   }
#
# \entry{
# \headword{kuukwana}
#   \glosses{
#     \gloss{filudo}
#   }
#
# \entry{
# \headword{siruúmani}
#   \glosses{
#   }
#
# \entry{
# \headword{japakɨ́ɨni}
#   \glosses{
#     \gloss{avispa}
#   }
#
# \entry{
# \headword{íti}
#   \glosses{
#     \gloss{transformarse}
#   }
#
# \entry{
# \headword{ampiisiítaakami}
#   \glosses{
#     \gloss{remedio.pl}
#   }
#
# \entry{
# \headword{sakumánaaja}
#   \glosses{
#     \gloss{el tronco de ungurahui; también llamado: ipɨɨti. PL: sakumánaajaka}
#   }
#
# \entry{
# \headword{ímani}
#   \glosses{
#     \gloss{mitayo.de.trampa}
#   }
#
# \entry{
# \headword{pɨɨta kitáaka}
#   \glosses{
#     \gloss{mujer.adulta.joven}
#   }
#
# \entry{
# \headword{turúunku}
#   \glosses{
#     \gloss{tronco}
#   }
#
# \entry{
# \headword{ramákatina}
#   \glosses{
#     \gloss{sitio barroso}
#   }
#
# \entry{
# \headword{kaasi katija}
#   \glosses{
#     \gloss{sachapapa.var}
#   }
#
# \entry{
# \headword{nɨɨku takuuyáana}
#   \glosses{
#     \gloss{persona.alta}
#   }
#
# \entry{
# \headword{siimúuni}
#   \glosses{1.
#     \gloss{curar.en}
#   }
#   \glosses{2.
#     \gloss{enseñar-chamanismo}
#   }
#
# \entry{
# \headword{apísikaka}
#   \glosses{
#     \gloss{racimo.vacio.pl}
#   }
#
# \entry{
# \headword{rapi}
#   \glosses{
#     \gloss{despedazar}
#   }
#
# \entry{
# \headword{tipi}
#   \glosses{
#     \gloss{topar}
#   }
#
# \entry{
# \headword{samuu}
#   \glosses{
#     \gloss{paiche, tipo de peje. PL: samuuwa}
#   }
#
# \entry{
# \headword{fecha}
#   \glosses{
#     \gloss{fecha}
#   }
#
# \entry{
# \headword{naaráaja}
#   \glosses{
#     \gloss{naranja}
#   }
#
# \entry{
# \headword{kinikuúraata}
#   \glosses{1.
#     \gloss{hacia.allá.río.arriba}
#   }
#   \glosses{2.
#     \gloss{hacia.allá.arriba}
#   }
#
# \entry{
# \headword{mukúuni}
#   \glosses{
#     \gloss{podrir, hablando de carne. Raíz: muku-}
#   }
#
# \entry{
# \headword{simaáyasi}
#   \glosses{
#     \gloss{chimaychi}
#   }
#
# \entry{
# \headword{kajíini}
#   \glosses{
#     \gloss{echar.mango}
#   }
#
# \entry{
# \headword{muújinaapɨ júnɨɨna}
#   \glosses{
#     \gloss{olor.a.yacuruna}
#   }
#
# \entry{
# \headword{radiograjíira}
#   \glosses{
#     \gloss{radiografía}
#   }
#
# \entry{
# \headword{=iyɨkúura}
#   \glosses{1.
#     \gloss{gracias.a}
#   }
#   \glosses{2.
#     \gloss{a.favor.de}
#   }
#   \glosses{3.
#     \gloss{contra}
#   }
#   \glosses{4.
#     \gloss{precio}
#   }
#
# \entry{
# \headword{naamiya}
#   \glosses{
#     \gloss{eye.pl}
#   }
#
# \entry{
# \headword{iyuwaajina}
#   \glosses{
#   }
#
# \entry{
# \headword{titi}
#   \glosses{
#     \gloss{desmamarse}
#   }
#
# \entry{
# \headword{iítijiita}
#   \glosses{
#   }
#
# \entry{
# \headword{papaanɨ́ɨni}
#   \glosses{
#     \gloss{hacerse.hueco}
#   }
#
# \entry{
# \headword{anijíki}
#   \glosses{
#     \gloss{enojarse}
#   }
#
# \entry{
# \headword{riitáaska}
#   \glosses{
#     \gloss{retazo}
#   }
#
# \entry{
# \headword{kanɨɨrana}
#   \glosses{
#     \gloss{cosa ajena o pertenencia de otra persona. No tiene forma plural}
#   }
#
# \entry{
# \headword{akásima}
#   \glosses{
#     \gloss{ingle}
#   }
#
# \entry{
# \headword{rikíjati}
#   \glosses{1.
#     \gloss{romperse.cuello}
#   }
#   \glosses{2.
#     \gloss{romperse.ifelo}
#   }
#
# \entry{
# \headword{káaji ijírɨna}
#   \glosses{
#     \gloss{soga.esp}
#   }
#
# \entry{
# \headword{ajiráani}
#   \glosses{
#     \gloss{latir o pulsar, hablando del corazon y la sangre. Raíz: ájiita-}
#   }
#
# \entry{
# \headword{piisíini}
#   \glosses{
#     \gloss{orinar}
#   }
#
# \entry{
# \headword{makika}
#   \glosses{
#     \gloss{yuca verde, comestible pero no bueno todavía. PL: makikaka}
#   }
#
# \entry{
# \headword{kanati}
#   \glosses{1.
#     \gloss{soltar}
#   }
#   \glosses{2.
#     \gloss{dejar.salir}
#   }
#
# \entry{
# \headword{riyuuka}
#   \glosses{
#     \gloss{cortadera}
#   }
#
# \entry{
# \headword{ániitaaja}
#   \glosses{
#     \gloss{carga, hablando de lo cargado en la espalda. PL: ániitaajaka}
#   }
#
# \entry{
# \headword{taataasíita}
#   \glosses{
#     \gloss{hermano/a.de.mujer.voc.aff}
#   }
#
# \entry{
# \headword{tiniisíini}
#   \glosses{
#     \gloss{teñir}
#   }
#
# \entry{
# \headword{kaayɨ́ɨni}
#   \glosses{
#     \gloss{tener alguien como peón o trabajador. Raíz: kaáyɨɨ-}
#   }
#
# \entry{
# \headword{ajiíti}
#   \glosses{
#     \gloss{estar.sentado}
#   }
#
# \entry{
# \headword{examinaásii}
#   \glosses{
#     \gloss{examinar}
#   }
#
# \entry{
# \headword{katɨ́yasi}
#   \glosses{
#     \gloss{persona.que.falta.muela}
#   }
#
# \entry{
# \headword{tiírakumaji}
#   \glosses{
#     \gloss{hacer.viniendo}
#   }
#
# \entry{
# \headword{kaapɨɨta}
#   \glosses{
#     \gloss{en cualquier momento}
#   }
#
# \entry{
# \headword{-jináa}
#   \glosses{
#     \gloss{NOMZ:ORIG}
#   }
#
# \entry{
# \headword{jaakaa}
#   \glosses{
#     \gloss{mono.blanco}
#   }
#
# \entry{
# \headword{desayunaasíini}
#   \glosses{
#     \gloss{desayunar}
#   }
#
# \entry{
# \headword{tiírajiina}
#   \glosses{
#     \gloss{de.allá}
#   }
#
# \entry{
# \headword{riimíiria}
#   \glosses{
#     \gloss{remedio}
#   }
#
# \entry{
# \headword{maki}
#   \glosses{
#     \gloss{soñar}
#   }
#
# \entry{
# \headword{kaasiija}
#   \glosses{
#     \gloss{tipo de piripiri, para sajino. PL: kaasiijaka}
#   }
#
# \entry{
# \headword{jɨɨ́timijaárika}
#   \glosses{
#     \gloss{algunitos.pl.inan}
#   }
#
# \entry{
# \headword{sɨɨ́sajakwaa}
#   \glosses{
#     \gloss{pequeño.para.algo.no.pequeño}
#   }
#
# \entry{
# \headword{kinimɨ́ɨra}
#   \glosses{1.
#     \gloss{más.abajo.hacia.destinario}
#   }
#   \glosses{2.
#     \gloss{más.río.abajo.hacia.destinario}
#   }
#
# \entry{
# \headword{nami}
#   \glosses{1.
#     \gloss{allá río abajo, hablando de un lugar ya mencionado}
#   }
#   \glosses{2.
#     \gloss{allá abajo, hablando de un lugar ya mencionado}
#   }
#   \glosses{3.
#     \gloss{allá adentro, hablando de un lugar ya mencionado}
#   }
#
# \entry{
# \headword{saáni}
#   \glosses{1.
#     \gloss{enderezarse}
#   }
#   \glosses{2.
#     \gloss{levantarse}
#   }
#
# \entry{
# \headword{paatríina}
#   \glosses{
#     \gloss{padrino}
#   }
#
# \entry{
# \headword{anapaakákiaakɨ}
#   \glosses{
#   }
#
# \entry{
# \headword{jɨɨ́tinurika}
#   \glosses{
#     \gloss{que.tamaño}
#   }
#
# \entry{
# \headword{ánaaka}
#   \glosses{
#     \gloss{tronco.pl}
#   }
#
# \entry{
# \headword{nɨɨku}
#   \glosses{1.
#     \gloss{altura de una cosa. PL: nɨɨkuku}
#   }
#   \glosses{2.
#     \gloss{alto}
#   }
#
# \entry{
# \headword{kariniwɨɨtáani}
#   \glosses{
#     \gloss{mirar.por.todos.lados}
#   }
#
# \entry{
# \headword{jawaárika}
#   \glosses{
#     \gloss{de.una.vez}
#   }
#
# \entry{
# \headword{mɨ́jɨɨtáana}
#   \glosses{
#     \gloss{persona.respetada}
#   }
#
# \entry{
# \headword{kanatɨ́ɨni}
#   \glosses{1.
#     \gloss{soltar}
#   }
#   \glosses{2.
#     \gloss{dejar.salir}
#   }
#
# \entry{
# \headword{tamuujúuni}
#   \glosses{1.
#     \gloss{chupar}
#   }
#   \glosses{2.
#     \gloss{tener.sexo}
#   }
#
# \entry{
# \headword{nasíkana}
#   \glosses{
#   }
#
# \entry{
# \headword{iínuunakíina}
#   \glosses{
#     \gloss{quillosisa}
#   }
#
# \entry{
# \headword{parina}
#   \glosses{
#     \gloss{anchura de una cosa. PL: parimi}
#   }
#
# \entry{
# \headword{atendiisíini}
#   \glosses{
#     \gloss{atender}
#   }
#
# \entry{
# \headword{-yuuri}
#   \glosses{
#     \gloss{PL}
#   }
#
# \entry{
# \headword{maáriji}
#   \glosses{
#     \gloss{intentar}
#   }
#
# \entry{
# \headword{deritiísii}
#   \glosses{
#     \gloss{derritirse}
#   }
#
# \entry{
# \headword{maakɨɨsíini}
#   \glosses{
#     \gloss{agarrar.con.llica}
#   }
#
# \entry{
# \headword{jɨɨ́tipɨjaárika}
#   \glosses{
#     \gloss{algunitos seres animados}
#   }
#
# \entry{
# \headword{anitáani}
#   \glosses{1.
#     \gloss{traer algo. Raíz: aníta-}
#   }
#   \glosses{2.
#     \gloss{venir trayendo a alguien. Raíz: aníta-}
#   }
#
# \entry{
# \headword{mɨ́nɨɨtáani}
#   \glosses{1.
#     \gloss{estar sombrío, hablando del clima. Raíz: mɨ́nɨɨta-}
#   }
#   \glosses{2.
#     \gloss{estar oscuro o indistinto, hablando de cualquier entidad. Raíz: mɨ́nɨɨta-}
#   }
#
# \entry{
# \headword{Tiítɨɨsi}
#   \glosses{
#     \gloss{nombre.personal}
#   }
#
# \entry{
# \headword{sakatɨ́ɨni}
#   \glosses{
#     \gloss{estrecharse en un sitio. Raíz: sakátɨ-, sakáti-}
#   }
#
# \entry{
# \headword{-waasa}
#   \glosses{
#     \gloss{CL:apertura}
#   }
#
# \entry{
# \headword{síraaka}
#   \glosses{
#   }
#
# \entry{
# \headword{iíjinakɨya}
#   \glosses{
#     \gloss{punta.pl}
#   }
#
# \entry{
# \headword{acordaasíini}
#   \glosses{
#     \gloss{acordarse.de}
#   }
#
# \entry{
# \headword{waarsásii}
#   \glosses{
#     \gloss{bailar.valse}
#   }
#
# \entry{
# \headword{júnɨɨna}
#   \glosses{1.
#     \gloss{aliento. PL: júnɨɨnaka}
#   }
#   \glosses{2.
#     \gloss{olor o perfume. PL: júnɨɨna}
#   }
#
# \entry{
# \headword{kaasiáasa}
#   \glosses{
#     \gloss{aguardiente o trago. Basado en el portugues: cachaça. PL: kaasiáasaka}
#   }
#
# \entry{
# \headword{nakikuuja marasi}
#   \glosses{
#   }
#
# \entry{
# \headword{nɨyaka}
#   \glosses{
#     \gloss{palidez, hablando de la piel de una persona enferma}
#   }
#
# \entry{
# \headword{Saákisa}
#   \glosses{
#     \gloss{personaje.histórico}
#   }
#
# \entry{
# \headword{maayitɨ́ɨsi}
#   \glosses{
#     \gloss{perdedor.de.hijos}
#   }
#
# \entry{
# \headword{ámusi}
#   \glosses{
#     \gloss{diente.carcomido}
#   }
#
# \entry{
# \headword{juríini}
#   \glosses{
#     \gloss{persona de una región indicada, por ejemplo: Anatimu juríini, persona del río Pintuyacu. PL: juríiniwaaka }
#   }
#
# \entry{
# \headword{ijúuti}
#   \glosses{
#     \gloss{aguja. PL: ijúutiwa}
#   }
#
# \entry{
# \headword{siitíina}
#   \glosses{
#     \gloss{polilla}
#   }
#
# \entry{
# \headword{naki páriiki}
#   \glosses{
#     \gloss{sonido.de.palo}
#   }
#
# \entry{
# \headword{tikitáani}
#   \glosses{
#     \gloss{inundarse}
#   }
#
# \entry{
# \headword{-maari}
#   \glosses{
#     \gloss{HABIT}
#   }
#
# \entry{
# \headword{muriyuujátina}
#   \glosses{
#     \gloss{pintado}
#   }
#
# \entry{
# \headword{-kuráana}
#   \glosses{
#     \gloss{REC.PST.REP}
#   }
#
# \entry{
# \headword{paniúura}
#   \glosses{
#     \gloss{pañuelo}
#   }
#
# \entry{
# \headword{animɨ}
#   \glosses{
#     \gloss{aleta de palo. PL: animɨya}
#   }
#
# \entry{
# \headword{ráana jirítiikɨ}
#   \glosses{
#     \gloss{amarrado.de.pecho.de.perdiz}
#   }
#
# \entry{
# \headword{aarawati}
#   \glosses{
#     \gloss{papaso.de.palmera}
#   }
#
# \entry{
# \headword{taakíira}
#   \glosses{
#     \gloss{por.otro.lado}
#   }
#
# \entry{
# \headword{kɨyatatáani}
#   \glosses{
#     \gloss{vomitar.para.otro}
#   }
#
# \entry{
# \headword{taaniwa}
#   \glosses{
#     \gloss{trampa.pl}
#   }
#
# \entry{
# \headword{reconosisíini}
#   \glosses{
#     \gloss{reconocer}
#   }
#
# \entry{
# \headword{naamiiji}
#   \glosses{1.
#     \gloss{desde.río.abajo}
#   }
#   \glosses{2.
#     \gloss{desde.abajo}
#   }
#
# \entry{
# \headword{saminiijúuni}
#   \glosses{
#     \gloss{pensamiento. PL: saminiijúunika}
#   }
#
# \entry{
# \headword{suukwariijaari}
#   \glosses{
#     \gloss{estilo de tejer el cedazo. PL: suukwariijaariwa, suukwariijarika}
#   }
#
# \entry{
# \headword{kinimɨɨ́raata}
#   \glosses{1.
#     \gloss{hacia.allá.río.abajo}
#   }
#   \glosses{2.
#     \gloss{hacia.allá.abajo}
#   }
#
# \entry{
# \headword{raatisana}
#   \glosses{
#     \gloss{bebida de cualquier tipo. PL: raatisami}
#   }
#
# \entry{
# \headword{kɨɨ́ti}
#   \glosses{1.
#     \gloss{pelarse}
#   }
#   \glosses{2.
#     \gloss{shed.skin}
# ...
#
# \entry{
# \headword{piriki}
#   \glosses{
#     \gloss{hacerce.mocho}
#   }
#
# \entry{
# \headword{samaríyuuja}
#   \glosses{
#     \gloss{suri.esp.}
#   }
#
# \entry{
# \headword{anirúyaaka}
#   \glosses{1.
#     \gloss{minga de tumbar. PL: anirúyaakaka}
#   }
#   \glosses{2.
#     \gloss{masato preparado para una minga de tumbar. PL: anirúyaakaka}
#   }
#
# \entry{
# \headword{muusáyuuti}
#   \glosses{
#     \gloss{isula.huayo}
#   }
#
# \entry{
# \headword{anákaaja}
#   \glosses{1.
#     \gloss{huashero}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{anitáaki makwaati}
#   \glosses{
#     \gloss{huangana sapo}
#   }
#
# \entry{
# \headword{kurika}
#   \glosses{
#     \gloss{mano. PL: kurikaka}
#   }
#
# \entry{
# \headword{majáani}
#   \glosses{1.
#     \gloss{azotar o chicotear. Raíz: maja-}
#   }
#   \glosses{2.
#     \gloss{dar un choque eléctrico, hablando de la anguilla. Raíz: majarɨɨ-}
#   }
#   \glosses{3.
#     \gloss{desmochar o limpiar una purma. Raíz: maja-}
#   }
#
# \entry{
# \headword{nɨrimɨɨ́tari}
#   \glosses{
#     \gloss{chacruna.var}
#   }
#
# \entry{
# \headword{Maasikuuri}
#   \glosses{
#     \gloss{subgrupo.iquito.de.Mazán}
#   }
#
# \entry{
# \headword{siyúuna}
#   \glosses{
#     \gloss{pinsha.caspi}
#   }
#
# \entry{
# \headword{maájarina}
#   \glosses{
#     \gloss{bola-bola}
#   }
#
# \entry{
# \headword{kajasi áraka}
#   \glosses{
#     \gloss{velluda}
#   }
#
# \entry{
# \headword{tasikɨ́ɨni}
#   \glosses{
#     \gloss{hacer tapaje, usando un tasikɨ. Raíz: tasíkɨɨ-}
#   }
#
# \entry{
# \headword{amúriija}
#   \glosses{
#     \gloss{molar. PL: amúriijaka}
#   }
#
# \entry{
# \headword{najiwɨ́niikíini}
#   \glosses{
#     \gloss{olfatear}
#   }
#
# \entry{
# \headword{nɨ́sirɨ}
#   \glosses{
#     \gloss{cotinga-roja.cuellinegro}
#   }
#
# \entry{
# \headword{anáani}
#   \glosses{
#     \gloss{roncar. Raíz: ána-}
#   }
#
# \entry{
# \headword{maruukiitáani}
#   \glosses{
#     \gloss{amarrar.piernas}
#   }
#
# \entry{
# \headword{iyarakátina}
#   \glosses{1.
#     \gloss{activo y energético, hablando de personas}
#   }
#   \glosses{2.
#     \gloss{ágil, hablando de ciertas personas y animales}
#   }
#
# \entry{
# \headword{yákuni}
#   \glosses{
#     \gloss{boa en general y también la anaconda del agua. PL: yákunika}
#   }
#
# \entry{
# \headword{nataajúuni}
#   \glosses{
#     \gloss{sembrar.poco.a.poco}
#   }
#
# \entry{
# \headword{Simɨraánaaka}
#   \glosses{1.
#     \gloss{personaje.histórico}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{kí=}
#   \glosses{
#     \gloss{yo, forma dependiente}
#   }
#
# \entry{
# \headword{anaasi}
#   \glosses{
#     \gloss{zancudo en general, un tipo de insecto. PL: anaasika}
#   }
#
# \entry{
# \headword{múkuutiríkana}
#   \glosses{
#     \gloss{yuca.var}
#   }
#
# \entry{
# \headword{siijúuni}
#   \glosses{
#     \gloss{puzangear}
#   }
#
# \entry{
# \headword{tiírakuma}
#   \glosses{
#     \gloss{allá, por ese camino}
#   }
#
# \entry{
# \headword{pururuuku}
#   \glosses{
#     \gloss{pururuca}
#   }
#
# \entry{
# \headword{kanɨɨrami}
#   \glosses{
#     \gloss{vergonzoso}
#   }
#
# \entry{
# \headword{nuníini}
#   \glosses{
#     \gloss{alumbrar. Raíz: nuni-}
#   }
#
# \entry{
# \headword{pirɨ́ɨni}
#   \glosses{
#     \gloss{tipo de tabaquero o arasari, tipo de ave. PL:  pirɨ́ɨnika, pirɨ́ɨniwa}
#   }
#
# \entry{
# \headword{aariímuya}
#   \glosses{
#     \gloss{manioc.var.}
#   }
#
# \entry{
# \headword{sawiti}
#   \glosses{
#     \gloss{uvilla, el árbol y sus frutos. PL: sawitika}
#   }
#
# \entry{
# \headword{sanáani}
#   \glosses{
#     \gloss{enderezar algo duro, por ejemplo un clavo. Raíz: saana-}
#   }
#
# \entry{
# \headword{tɨ́ɨni}
#   \glosses{
#     \gloss{''no sé!''}
#   }
#
# \entry{
# \headword{jiímana}
#   \glosses{
#     \gloss{suave}
#   }
#
# \entry{
# \headword{íti}
#   \glosses{
#     \gloss{caerse}
#   }
#
# \entry{
# \headword{anasɨ́ɨni}
#   \glosses{
#     \gloss{sentir dolor. Raíz: anásɨɨ-}
#   }
#
# \entry{
# \headword{íiyɨ}
#   \glosses{1.
#     \gloss{labio. PL: íiyɨwa, íiyɨka}
#   }
#   \glosses{2.
#     \gloss{canto o borde de una cosa, por ejemplo del río. PL: íiyɨwa, íiyɨka}
#   }
#
# \entry{
# \headword{kúrina}
#   \glosses{
#     \gloss{mullaca.caspi}
#   }
#
# \entry{
# \headword{sikɨɨtakúuni}
#   \glosses{
#     \gloss{lombríz.esp.}
#   }
#
# \entry{
# \headword{iika takáana}
#   \glosses{
#     \gloss{punta.de.lanza.demontable}
#   }
#
# \entry{
# \headword{pasɨɨmɨ}
#   \glosses{
#     \gloss{calzón.panga}
#   }
#
# \entry{
# \headword{muyuunɨ́ɨni}
#   \glosses{
#     \gloss{arquearse}
#   }
#
# \entry{
# \headword{kuyɨ́ɨsi}
#   \glosses{
#     \gloss{pava del monte. PL: kuyɨ́ɨsika}
#   }
#
# \entry{
# \headword{muujináana}
#   \glosses{
#     \gloss{yacuruna.caspi}
#   }
#
# \entry{
# \headword{nɨsikánaaja}
#   \glosses{
#     \gloss{tronco de aguaje. PL: nɨsikánaajaka}
#   }
#
# \entry{
# \headword{kamíkiika}
#   \glosses{1.
#     \gloss{ir.sin.parar.río.arriba}
#   }
#   \glosses{2.
#     \gloss{derecho}
#   }
#   \glosses{3.
#     \gloss{derecho.río.arriba}
#   }
#
# \entry{
# \headword{pɨɨka}
#   \glosses{
#     \gloss{tipo de sapo chico que vive en los charcos. PL: pɨɨkaka}
#   }
#
# \entry{
# \headword{wákii}
#   \glosses{
#     \gloss{sacha shimbillo, especie de árbol y sus frutos. PL: wákiiwa}
#   }
#
# \entry{
# \headword{aátamajániisana}
#   \glosses{
#     \gloss{hermano finado de varón. PL: atamajániisanawaaka}
#   }
#
# \entry{
# \headword{amaaka}
#   \glosses{
#     \gloss{un palo delgado, generalmente derecho y bien raspadito, que se usa en una construcción o como un bastón. PL: amaakaka}
#   }
#
# \entry{
# \headword{siritíini}
#   \glosses{
#     \gloss{agacharse.parado}
#   }
#
# \entry{
# \headword{nɨsikáriiyɨ}
#   \glosses{
#     \gloss{nacanaca}
#   }
#
# \entry{
# \headword{namisu}
#   \glosses{
#     \gloss{golondrina, tipo de ave. PL: namisuwa}
#   }
#
# \entry{
# \headword{ririikɨ́ɨni}
#   \glosses{
#     \gloss{regarse. Raíz: ririíkɨ-}
#   }
#
# \entry{
# \headword{suúkwarana}
#   \glosses{
#     \gloss{sucio}
#   }
#
# \entry{
# \headword{níiya=karikuku}
#   \glosses{
#     \gloss{cielo. No hay forma plural}
#   }
#
# \entry{
# \headword{minikɨɨkɨ́ɨni}
#   \glosses{
#     \gloss{sacudirse, hablando del cuerpo de uno. Raíz: minikɨɨ́kɨɨ-}
#   }
#
# \entry{
# \headword{amaniikúuni}
#   \glosses{1.
#     \gloss{golpear repetidamente, por ejemplo un bombo. Raíz: amaniíkuu-}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{aakanaajúuni}
#   \glosses{
#     \gloss{pulir}
#   }
#
# \entry{
# \headword{kumaku}
#   \glosses{1.
#     \gloss{viejo, hablando de cosas o seres}
#   }
#   \glosses{2.
#     \gloss{hombre viejo. PL: kumakuka}
#   }
#
# \entry{
# \headword{anapaakákana}
#   \glosses{
#     \gloss{yuca.var.}
#   }
#
# \entry{
# \headword{kusi pákɨɨti}
#   \glosses{
#     \gloss{araña.esp.}
#   }
#
# \entry{
# \headword{maákuwa}
#   \glosses{
#     \gloss{cunchi.esp}
#   }
#
# \entry{
# \headword{nasikatánaaja}
#   \glosses{
#     \gloss{cepa.sobrada}
#   }
#
# \entry{
# \headword{kí=}
#   \glosses{
#     \gloss{mi, mio o de mi}
#   }
#
# \entry{
# \headword{sitáani}
#   \glosses{
#     \gloss{desescamar, hablando de pescado o aguaje. Raíz: sita-}
#   }
#
# \entry{
# \headword{siíruwa}
#   \glosses{
#     \gloss{mono.choro.pl}
#   }
#
# \entry{
# \headword{jimuúkujina}
#   \glosses{
#     \gloss{sepulcro, hablando del espacio donde un difunto ha sido enterrado. PL: jimuukúkajina}
#   }
#
# \entry{
# \headword{iyúusi}
#   \glosses{
#     \gloss{nido de ave o mamífero. PL: iyúusika}
#   }
#
# \entry{
# \headword{kutɨ́ɨni}
#   \glosses{
#     \gloss{dar a luz o parir. Raíz: kutɨɨ-}
#   }
#
# \entry{
# \headword{kwaarɨ́yaaka}
#   \glosses{1.
#     \gloss{minga de cultivar. PL: kwaarɨ́yaakaka}
#   }
#   \glosses{2.
#     \gloss{masato preparado para una minga de cultivar. PL: kwaarɨ́yaakaka}
#   }
#
# \entry{
# \headword{maasi}
#   \glosses{
#     \gloss{llica. PL: maasika}
#   }
#
# \entry{
# \headword{awuúkwaja}
#   \glosses{
#     \gloss{"¡no importa!"}
#   }
#
# \entry{
# \headword{kujímani}
#   \glosses{1.
#     \gloss{compañero o compañera. PL: kujímaka}
#   }
#   \glosses{2.
#   }
#
# \entry{
# \headword{tamɨ́nɨɨna}
#   \glosses{
#     \gloss{busilo, un relámpago visto de lejos. PL: tamɨ́nɨɨnaka}
#   }
#
# \entry{
# \headword{iyákumata}
#   \glosses{
#     \gloss{rápido}
#   }
#
# \entry{
# \headword{kapíjiisi}
#   \glosses{
#     \gloss{olla.para.sudar.yuca}
#   }
#
# \entry{
# \headword{amatɨ́ɨni}
#   \glosses{
#     \gloss{abrirse}
#   }
#
# \entry{
# \headword{karíkuuyáana}
#   \glosses{
#     \gloss{malagüero}
#   }
#
# \entry{
# \headword{titika ijákɨɨsɨɨja}
#   \glosses{
#     \gloss{pie.lajoso}
#   }
#
# \entry{
# \headword{suríini}
#   \glosses{
#     \gloss{brillar fuerte el sol. Raíz: súrii-}
#   }
#
# \entry{
# \headword{titi}
#   \glosses{
#     \gloss{zafarse}
#   }
#
# \entry{
# \headword{riyájɨɨ}
#   \glosses{
#     \gloss{palisangre, tipo de árbol. PL: riyájɨɨwa}
#   }
#
# \entry{
# \headword{tatɨni}
#   \glosses{
#     \gloss{gavilán atrevido o halcón cazamurciélagos. PL: tatɨniwa, tatɨnika}
#   }
#
# \entry{
# \headword{aamuuniíraana}
#   \glosses{
#     \gloss{chacruna.var}
#   }
#
# \entry{
# \headword{aríyasi}
#   \glosses{
#     \gloss{escroto}
#   }
#
# \entry{
# \headword{mɨɨ́riaaka}
#   \glosses{
#     \gloss{patco}
#   }
#
# \entry{
# \headword{kanasi}
#   \glosses{
#     \gloss{lobo del río o nutria grande, tipo de mamífero. PL: kanasika}
#   }
#
# \entry{
# \headword{kuwíini}
#   \glosses{
#     \gloss{hacerse o volverse en algo. Raíz: kuúki-}
#   }
#
# \entry{
# \headword{kurija}
#   \glosses{
#     \gloss{muñeca o tobillo. PL: kurijaka, kurijakɨya}
#   }
#
# \entry{
# \headword{iíkuku}
#   \glosses{1.
#     \gloss{superficie}
#   }
#   \glosses{2.
#     \gloss{superficie.de.cuerpo}
#   }
#
# \entry{
# \headword{jiwíriku}
#   \glosses{
#     \gloss{ave.esp}
#   }
#
# \entry{
# \headword{apɨɨsíini}
#   \glosses{
#     \gloss{ponerse.falda}
#   }
#
# \entry{
# \headword{saasakíkwaa}
#   \glosses{
#     \gloss{toé}
#   }
#
# \entry{
# \headword{kariyúuka}
#   \glosses{
#     \gloss{carioca}
#   }
#
# \entry{
# \headword{ariíkuma}
#   \glosses{
#     \gloss{hombro. PL: ariíkumaka}
#   }
#
# \entry{
# \headword{maatɨ́yuuti}
#   \glosses{
#     \gloss{marupá}
#   }
#
# \entry{
# \headword{túruu}
#   \glosses{
#     \gloss{sapo motor. PL: túruuwa}
#   }
#
# \entry{
# \headword{saakaa=aákuji}
#   \glosses{
#     \gloss{por qué, palabra de pregunta}
#   }
#
# \entry{
# \headword{suwaramaajɨtáapɨ}
#   \glosses{
#     \gloss{cuatro, hablando de seres animados}
#   }
#
# \entry{
# \headword{siiturúkana}
#   \glosses{
#     \gloss{yuca.var.}
#   }
#
# \entry{
# \headword{pukíraati}
#   \glosses{
#     \gloss{cascarillo}
#   }
#
# \entry{
# \headword{naapíinu}
#   \glosses{
#     \gloss{yuca.var}
#   }
#
# \entry{
# \headword{maatɨ́ɨni}
#   \glosses{
#     \gloss{subir una cosa. Raíz: maatɨɨ-}
#   }
#
# \entry{
# \headword{irúuna}
#   \glosses{
#     \gloss{barandilla}
#   }
#
# \entry{
# \headword{paápaka simɨráana}
#   \glosses{
#     \gloss{sacha.parinari}
#   }
#
# \entry{
# \headword{ampiisiítaaja}
#   \glosses{
#     \gloss{remedio, sea de botica o vegetal. PL: ampiisiítaakami}
#   }
#
# \entry{
# \headword{siaakuruusíini}
#   \glosses{
#     \gloss{mezclar}
#   }
#
# \entry{
# \headword{iitiíraata}
#   \glosses{
#     \gloss{por.acá}
#   }
#
# \entry{
# \headword{siirɨ ítɨɨnɨyáana}
#   \glosses{
#     \gloss{lagarto trueno}
#   }
#
# \entry{
# \headword{isítina}
#   \glosses{
#     \gloss{hondo}
#   }
#
# \entry{
# \headword{múyuujáana}
#   \glosses{
#     \gloss{variedad de pijuayo que produce dos tamaños de frutos a la vez, el tipo más pequeño sin semilla, también conocido como pacutilla. PL: múyuujaánaka}
#   }
#
# \entry{
# \headword{=iyikúura}
#   \glosses{1.
#     \gloss{gracias.a}
#   }
#   \glosses{2.
#     \gloss{a.favor.de}
#   }
#   \glosses{3.
#     \gloss{contra}
#   }
#
# \entry{
# \headword{amariyaaja}
#   \glosses{
#     \gloss{pijuayo, la palmera y su huayo. PL: amariyaajaka}
#   }
#
# \entry{
# \headword{rapi}
#   \glosses{
#     \gloss{hacerse.pedazos}
#   }
#
# \entry{
# \headword{iiti}
#   \glosses{
#     \gloss{acá, en el lugar del hablante. Ver también: iiku, iima}
#   }
#
# \entry{
# \headword{isáani}
#   \glosses{
#     \gloss{orinar. Raíz: ísa-}
#   }
#
# \entry{
# \headword{kajatáani}
#   \glosses{
#     \gloss{sacar pelo o desplumar. Raíz: kajata-}
#   }
#
# \entry{
# \headword{maniákaaja}
#   \glosses{
#     \gloss{bujurqui.esp}
#   }
#
# \entry{
# \headword{jaanɨ́ɨti}
#   \glosses{
#     \gloss{shiwi. PL: jaanɨ́ɨtika}
#   }
#
# \entry{
# \headword{rɨɨka}
#   \glosses{
#     \gloss{varillal, una zona del monte. PL: rɨɨkaka}
#   }
#
# \entry{
# \headword{saakɨ́ɨni}
#   \glosses{
#     \gloss{cuento o historia. PL:  saakɨ́ɨnika}
#   }
#
# \entry{
# \headword{kumakija}
#   \glosses{
#     \gloss{suri en general. PL: kuumaki}
#   }
#
# \entry{
# \headword{kúsɨɨti}
#   \glosses{
#     \gloss{tamal o humita. PL: kúsɨɨtika}
#   }
#
# \entry{
# \headword{anisitáani}
#   \glosses{
#     \gloss{desastillar}
#   }
#
# \entry{
# \headword{sikwaranɨ́ɨni}
#   \glosses{
#     \gloss{asquear o tener asco a algo. Raíz: sikwaranɨɨ-}
#   }
#
# \entry{
# \headword{=na}
#   \glosses{
#     \gloss{CLF}
#   }
#
# \entry{
# \headword{anitáaki kajakáana}
#   \glosses{
#     \gloss{yarinilla.esp}
#   }
#
# \entry{
# \headword{jinakuma}
#   \glosses{1.
#     \gloss{adentro de}
#   }
#   \glosses{2.
#     \gloss{en, hablando de la cuenca de un rio}
#   }
#
# \entry{
# \headword{nakutáani}
#   \glosses{
#     \gloss{desgajar.racimo}
#   }
#
# \entry{
# \headword{kaanaji}
#   \glosses{
#     \gloss{seguridad}
#   }
#
# \entry{
# \headword{mukúraasi}
#   \glosses{
#     \gloss{vulva}
#   }
#
# \entry{
# \headword{tatɨɨ imɨ́ɨni}
#   \glosses{
#     \gloss{madre.del.emponado}
#   }
#
# \entry{
# \headword{iyajatɨ́ɨni}
#   \glosses{
#     \gloss{perder}
#   }
#
# \entry{
# \headword{paapáayɨ}
#   \glosses{
#     \gloss{papaya. Basado en el castellano: papaya. PL: paapáayɨka}
#   }
#
# \entry{
# \headword{simiiti}
#   \glosses{1.
#     \gloss{asipa}
#   }
#   \glosses{2.
#     \gloss{cresta}
#   }
#
# \entry{
# \headword{rikijatáani}
#   \glosses{1.
#     \gloss{romper.cuello}
#   }
#   \glosses{2.
#     \gloss{romper.ifelo}
#   }
#
# \entry{
# \headword{anijikúuni}
#   \glosses{
#     \gloss{hacer enojar o rabiar a alguien. Raíz: anijíkuu-}
#   }
#
# \entry{
# \headword{iitakajina}
#   \glosses{
#     \gloss{caserío, pueblo, ciudad o cualquier lugar poblado. No hay forma plural}
#   }
#
# \entry{
# \headword{iísuuwa}
#   \glosses{
#     \gloss{carachupa.pl}
#   }
#
# \entry{
# \headword{aaka}
#   \glosses{1.
#     \gloss{agua en general. No hay forma plural}
#   }
#   \glosses{2.
#     \gloss{río. PL: aakaka}
#   }
#   \glosses{3.
#     \gloss{resina aguada de una planta o un árbol. PL: aakaka}
#   }
#   \glosses{4.
#     \gloss{miel de abeja. No hay forma plural}
#   }
#
# \entry{
# \headword{iijutáani}
#   \glosses{1.
#     \gloss{abrir, por ejemplo una puerta o botella. Raíz: íjuta-}
#   }
#   \glosses{2.
#     \gloss{desabrigar. Raíz: íjuta-}
#   }
#   \glosses{3.
#     \gloss{destapar. Raíz: íjuta-}
#   }
#
# \entry{
# \headword{kaajáani}
#   \glosses{
#     \gloss{labrar}
#   }
#
# \entry{
# \headword{muwɨ́ɨna}
#   \glosses{
#     \gloss{machimango.blanco}
#   }
#
# \entry{
# \headword{sajíriisana}
#   \glosses{
#     \gloss{abuela finada o bisabuela finada. PL: sajíriisanawaaka}
#   }
#
# \entry{
# \headword{asimatíini}
#   \glosses{1.
#     \gloss{pisotear}
#   }
#   \glosses{2.
#     \gloss{patear.varias.veces}
#   }
#
# \entry{
# \headword{rikijatɨ́ɨni}
#   \glosses{1.
#     \gloss{romper el cuello}
#   }
#   \glosses{2.
#     \gloss{romperse.ifelo}
#   }
#
# \entry{
# \headword{ranaja}
#   \glosses{
#     \gloss{incordio, una glándula linfática. PL: ranajaka}
#   }
#
# \entry{
# \headword{anásana}
#   \glosses{
#     \gloss{doloroso}
#   }
#
# \entry{
# \headword{jinakuna}
#   \glosses{
#     \gloss{chontaquiro, especie de árbol. PL: jinakunaka}
#   }
#
# \entry{
# \headword{kisaati}
#   \glosses{
#     \gloss{tipo de cumala, especie de árbol. PL: kisaatika}
#   }
#
# \entry{
# \headword{sapɨɨja}
#   \glosses{
#     \gloss{yuca.ecapado}
#   }
#
# \entry{
# \headword{kiiwaja}
#   \glosses{
#     \gloss{"dame!" o "dámelo!"}
#   }
#
# \entry{
# \headword{maámaati}
#   \glosses{
#     \gloss{sapo mau mau. PL: maámaatika}
#   }
#
# \entry{
# \headword{tamɨ́ɨka}
#   \glosses{
#     \gloss{hormiga.de.tangarana}
#   }
#
# \entry{
# \headword{suruku}
#   \glosses{
#     \gloss{arambasa, tipo de abeja que produce miel comestible. PL: surukuka, surukuwa}
#   }
#
# \entry{
# \headword{paniwɨ}
#   \glosses{
#     \gloss{shitari}
#   }
#
# \entry{
# \headword{kaamiíraata}
#   \glosses{1.
#     \gloss{hacia río arriba}
#   }
#   \glosses{2.
#     \gloss{hacia arriba}
#   }
#
# \entry{
# \headword{jawakɨ́ɨni}
#   \glosses{1.
#     \gloss{secarse un líquido. Raíz: jawakɨɨ-}
#   }
#   \glosses{2.
#     \gloss{secarse la garganta. Raíz: jawakɨɨ-}
#   }
#
# \entry{
# \headword{kásami}
#   \glosses{1.
#     \gloss{cosas o pertenencias de alguien. PL: kasámika}
#   }
#   \glosses{2.
#     \gloss{mercadería de un patrón. Siempre usado en esta forma plural}
#   }
#
# \entry{
# \headword{iyúuna}
#   \glosses{
#     \gloss{subidera o subidor, un palo que se se usa para poder subir y recoger huayos de otro árbol. PL: iyúunaka}
#   }
#
# \entry{
# \headword{kasiráani}
#   \glosses{1.
#     \gloss{agarrar, hablando de la acción de la mano. Raíz: kásiita-}
#   }
#   \glosses{2.
#     \gloss{tener algo en mano. Raíz: kásiita-}
#   }
#   \glosses{3.
#     \gloss{contagiar, hablando de una enfermedad. Raíz: kásiita-}
#   }
#
# \entry{
# \headword{iikujiita}
#   \glosses{1.
#     \gloss{acá.río.arribita}
#   }
#   \glosses{2.
#     \gloss{acá.arribita}
#   }

# %%
e = root.find('entry[@guid="531fc799-4cf2-4bd6-b331-ec17612d4cc4"]')
nodetext(e.find('citation/form[@lang="iqu"]/text')) #/form[@lang="iqu"]/text')
get_headword(e)
# Out:
# 'ajanɨ́ɨni'

# %% [markdown]
# ## Reversal dictionary
#
# The entries in the  'Reversals' section is relatively simple, and consists of the following fields:
#
# 1. Reversal Entries (Spn)
# 2. Gram. info
# 3. Citation Form

# %%
tree = ET.parse(reversaldict)
root = tree.getroot()

entries = root.findall('.//default:div[@class="reversalindexentry"]', ns)

# %%
for e in entries:
    hdwd = e.find('default:span[@lang="es"]', ns)
    gram = e.find('.//default:span[@class="ownertype_abbreviation"]', ns)
    gloss = e.find('.//default:span[@lang="ga"]', ns)
    # Variants???
    print(
        '\entry{',
        '\hdwd{', nodetext(hdwd), '}',
        '\gram{', nodetext(gram), '}',
        '\gloss{', nodetext(gloss), '}',
        '}'
    )
# Out:
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# ...
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{ compare } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
# \entry{ \hdwd{  } \gram{  } \gloss{  } }
